# %% [markdown]
# # Requirements

# %%
import pandas as pd

# %%
# Add as many imports as you need.
# Add as many imports as you need.
import pandas as pd

from VNP.packages.data_alalysis import *
from VNP.packages.data_preperation import *
from VNP.packages.missing_values import *
from VNP.packages.visualization import *
from VNP.packages.models import *
from VNP.packages.evaluation import *
from VNP.packages.vnp_ez import *
# %load_ext autoreload
# %autoreload 2

# %%
from keras.api.models import Sequential
from keras.api.layers import Input, LSTM, Dense
import keras

# %% [markdown]
# # Laboratory Exercise - Run Mode (8 points)

# %% [markdown]
# ## Introduction
# In this laboratory assignment, the focus is on time series forecasting, specifically targeting the prediction of the current **average sea-level pressure** in the city of Skopje. Your task involves employing bagging and boosting methods to forecast the average sea-level pressure. To accomplish this, you will use data from the preceding three days, consisting of average, minimal, and maximal temperatures, precipitation, as well as wind direction and speed, and the current season. By applying these ensemble learning techniques, you aim to enhance the accuracy and reliability of your predictions, gaining valuable insights into the temporal dynamics of sea-level pressure based on the given meteorological variables.
#
# **Note: You are required to perform this laboratory assignment on your local machine.**

# %% [markdown]
# ## The Weather Dataset

# %% [markdown]
# ## Exploring the Weather Dataset
# This dataset consists of daily weather records for the city of Skopje from January 1, 2021, to August 1, 2023. Each entry includes a unique station ID, city name, date, corresponding season (e.g., summer, winter), and various meteorological parameters such as average, minimum, and maximum temperatures in Celsius, precipitation in millimeters, average wind direction in degrees, average wind speed in kilometers per hour, and average sea-level pressure in hectopascals. The dataset offers comprehensive insights into the climatic conditions, allowing for analysis and exploration of weather patterns in Skopje over the specified time period.
#
# The dataset comprises the following columns:
# - station_id - unique ID for the weather station,
# - city_name - name of the city where the station is located,
# - date - date of the weather record,
# - season - season corresponding to the date (e.g., summer, winter),
# - avg_temp_c - average temperature in Celsius,
# - min_temp_c - minimum temperature in Celsius,
# - max_temp_c - maximum temperature in Celsius,
# - precipitation_mm - precipitation in millimeters,
# - avg_wind_dir_deg - average wind direction in degrees,
# - avg_wind_speed_kmh - average wind speed in kilometers per hour, and
# - avg_sea_level_pres_hpa - average sea-level pressure in hectopascals.
#
# *Note: The dataset is complete, with no missing values in any of its entries.*

# %% [markdown]
# Load the dataset into a `pandas` data frame.

# %%
# Write your code here. Add as many boxes as you need.
df = pd.read_csv("../data/weather.csv")

# %%
df_1 = df.drop(columns=["city_name", "station_id"])

# %%
df_1
# Out:
#            date  season  avg_temp_c  min_temp_c  max_temp_c  precipitation_mm  \
# 0    2021-01-01  Winter         5.1         0.5        13.2               0.0
# 1    2021-01-02  Winter         3.0        -2.6        11.2               0.0
# 2    2021-01-03  Winter         6.8         3.5        12.5               1.3
# 3    2021-01-04  Winter         6.6         6.1         7.2               3.6
# 4    2021-01-05  Winter         4.3         2.3         6.7               4.6
# ..          ...     ...         ...         ...         ...               ...
# 938  2023-07-28  Summer        22.8        12.3        32.7               0.0
# 939  2023-07-29  Summer        26.3        16.3        35.4               0.0
# 940  2023-07-30  Summer        28.2        19.5        36.4               0.0
# 941  2023-07-31  Summer        25.8        20.9        32.1               0.0
# 942  2023-08-01  Summer        25.8        17.3        33.9               0.0
#
#      avg_wind_dir_deg  avg_wind_speed_kmh  avg_sea_level_pres_hpa
# 0               330.0                 5.9                  1021.2
# 1               330.0                 5.9                  1021.2
# 2               339.0                 8.0                  1017.8
# 3               298.0                 5.3                  1011.3
# 4                11.0                 5.1                  1014.5
# ..                ...                 ...                     ...
# 938               2.0                 6.8                  1014.6
# 939             261.0                 6.2                  1011.7
# 940             317.0                 8.0                  1009.8
# 941             307.0                12.3                  1010.9
# 942             309.0                 8.0                  1008.7
#
# [943 rows x 9 columns]

# %%
df_1["date"] = pd.to_datetime(df_1["date"])
df_1.set_index(keys=["date"], inplace=True)
df_1.sort_index(inplace=True)

# %%
df_1
# Out:
#             season  avg_temp_c  min_temp_c  max_temp_c  precipitation_mm  \
# date
# 2021-01-01  Winter         5.1         0.5        13.2               0.0
# 2021-01-02  Winter         3.0        -2.6        11.2               0.0
# 2021-01-03  Winter         6.8         3.5        12.5               1.3
# 2021-01-04  Winter         6.6         6.1         7.2               3.6
# 2021-01-05  Winter         4.3         2.3         6.7               4.6
# ...            ...         ...         ...         ...               ...
# 2023-07-28  Summer        22.8        12.3        32.7               0.0
# 2023-07-29  Summer        26.3        16.3        35.4               0.0
# 2023-07-30  Summer        28.2        19.5        36.4               0.0
# 2023-07-31  Summer        25.8        20.9        32.1               0.0
# 2023-08-01  Summer        25.8        17.3        33.9               0.0
#
#             avg_wind_dir_deg  avg_wind_speed_kmh  avg_sea_level_pres_hpa
# date
# 2021-01-01             330.0                 5.9                  1021.2
# 2021-01-02             330.0                 5.9                  1021.2
# 2021-01-03             339.0                 8.0                  1017.8
# 2021-01-04             298.0                 5.3                  1011.3
# 2021-01-05              11.0                 5.1                  1014.5
# ...                      ...                 ...                     ...
# 2023-07-28               2.0                 6.8                  1014.6
# 2023-07-29             261.0                 6.2                  1011.7
# 2023-07-30             317.0                 8.0                  1009.8
# 2023-07-31             307.0                12.3                  1010.9
# 2023-08-01             309.0                 8.0                  1008.7
#
# [943 rows x 8 columns]

# %%
df_1.isna().sum()
# Out:
# season                    0
# avg_temp_c                0
# min_temp_c                0
# max_temp_c                0
# precipitation_mm          0
# avg_wind_dir_deg          0
# avg_wind_speed_kmh        0
# avg_sea_level_pres_hpa    0
# dtype: int64

# %%
df_1.columns
# Out:
# Index(['season', 'avg_temp_c', 'min_temp_c', 'max_temp_c', 'precipitation_mm',
#        'avg_wind_dir_deg', 'avg_wind_speed_kmh', 'avg_sea_level_pres_hpa'],
#       dtype='object')

# %%
num_features = ['avg_temp_c', 'precipitation_mm',
       'avg_wind_dir_deg', 'avg_wind_speed_kmh', 'avg_sea_level_pres_hpa']

# %%
sns.heatmap(df_1[num_features].corr(), annot=True)
# Out:
# <Axes: >

# %%
df_2 = df_1.drop(columns="max_temp_c")

# %%
sns.heatmap(df_2[num_features].corr(), annot=True)
# Out:
# <Axes: >

# %%
df_3 = df_2.drop(columns="min_temp_c")

# %%
sns.heatmap(df_2[num_features].corr(), annot=True)
# Out:
# <Axes: >

# %%
sns.pairplot(df_3[num_features])

# %%
lags = range(3, 0, -1)
list(lags)
# Out:
# [3, 2, 1]

# %%
target = 'avg_sea_level_pres_hpa'

# %%
for lag in lags:
    for column in num_features:
        df_3[f"{column}_{lag}"] = df_3[column].shift(lag)

# %%
features = ['avg_temp_c', 'precipitation_mm',
       'avg_wind_dir_deg', 'avg_wind_speed_kmh']

# %%
df_4 = df_3.drop(columns=features)

# %%
df_5 = df_4.dropna()

# %%
df_5
# Out:
#             season  avg_sea_level_pres_hpa  avg_temp_c_3  precipitation_mm_3  \
# date
# 2021-01-04  Winter                  1011.3           5.1                 0.0
# 2021-01-05  Winter                  1014.5           3.0                 0.0
# 2021-01-06  Winter                  1017.2           6.8                 1.3
# 2021-01-07  Winter                  1015.2           6.6                 3.6
# 2021-01-08  Winter                  1009.7           4.3                 4.6
# ...            ...                     ...           ...                 ...
# 2023-07-28  Summer                  1014.6          29.2                 0.0
# 2023-07-29  Summer                  1011.7          28.2                 0.0
# 2023-07-30  Summer                  1009.8          20.7                 0.0
# 2023-07-31  Summer                  1010.9          22.8                 0.0
# 2023-08-01  Summer                  1008.7          26.3                 0.0
#
#             avg_wind_dir_deg_3  avg_wind_speed_kmh_3  \
# date
# 2021-01-04               330.0                   5.9
# 2021-01-05               330.0                   5.9
# 2021-01-06               339.0                   8.0
# 2021-01-07               298.0                   5.3
# 2021-01-08                11.0                   5.1
# ...                        ...                   ...
# 2023-07-28               275.0                   4.7
# 2023-07-29               242.0                  13.4
# 2023-07-30               316.0                  16.0
# 2023-07-31                 2.0                   6.8
# 2023-08-01               261.0                   6.2
#
#             avg_sea_level_pres_hpa_3  avg_temp_c_2  precipitation_mm_2  \
# date
# 2021-01-04                    1021.2           3.0                 0.0
# 2021-01-05                    1021.2           6.8                 1.3
# 2021-01-06                    1017.8           6.6                 3.6
# 2021-01-07                    1011.3           4.3                 4.6
# 2021-01-08                    1014.5           6.2                 0.0
# ...                              ...           ...                 ...
# 2023-07-28                    1007.7          28.2                 0.0
# 2023-07-29                    1002.9          20.7                 0.0
# 2023-07-30                    1012.6          22.8                 0.0
# 2023-07-31                    1014.6          26.3                 0.0
# 2023-08-01                    1011.7          28.2                 0.0
#
#             avg_wind_dir_deg_2  avg_wind_speed_kmh_2  \
# date
# 2021-01-04               330.0                   5.9
# 2021-01-05               339.0                   8.0
# 2021-01-06               298.0                   5.3
# 2021-01-07                11.0                   5.1
# 2021-01-08                18.0                   6.7
# ...                        ...                   ...
# 2023-07-28               242.0                  13.4
# 2023-07-29               316.0                  16.0
# 2023-07-30                 2.0                   6.8
# 2023-07-31               261.0                   6.2
# 2023-08-01               317.0                   8.0
#
#             avg_sea_level_pres_hpa_2  avg_temp_c_1  precipitation_mm_1  \
# date
# 2021-01-04                    1021.2           6.8                 1.3
# 2021-01-05                    1017.8           6.6                 3.6
# 2021-01-06                    1011.3           4.3                 4.6
# 2021-01-07                    1014.5           6.2                 0.0
# 2021-01-08                    1017.2           7.3                 0.5
# ...                              ...           ...                 ...
# 2023-07-28                    1002.9          20.7                 0.0
# 2023-07-29                    1012.6          22.8                 0.0
# 2023-07-30                    1014.6          26.3                 0.0
# 2023-07-31                    1011.7          28.2                 0.0
# 2023-08-01                    1009.8          25.8                 0.0
#
#             avg_wind_dir_deg_1  avg_wind_speed_kmh_1  avg_sea_level_pres_hpa_1
# date
# 2021-01-04               339.0                   8.0                    1017.8
# 2021-01-05               298.0                   5.3                    1011.3
# 2021-01-06                11.0                   5.1                    1014.5
# 2021-01-07                18.0                   6.7                    1017.2
# 2021-01-08                 0.0                   4.5                    1015.2
# ...                        ...                   ...                       ...
# 2023-07-28               316.0                  16.0                    1012.6
# 2023-07-29                 2.0                   6.8                    1014.6
# 2023-07-30               261.0                   6.2                    1011.7
# 2023-07-31               317.0                   8.0                    1009.8
# 2023-08-01               307.0                  12.3                    1010.9
#
# [940 rows x 17 columns]

# %%
one_hot_season = pd.get_dummies(df_5["season"], ).replace(True, 1).replace(False, 0)
# Out:
# C:\Users\User-PC\AppData\Local\Temp\ipykernel_24588\3537968524.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   one_hot_season = pd.get_dummies(df_5["season"], ).replace(True, 1).replace(False, 0)

# %%
df_6 = pd.concat([df_5,one_hot_season], axis=1)

# %%
df_6 = pd.concat([df_6,one_hot_season], axis=1)

# %%
df_6
# Out:
#             season  avg_sea_level_pres_hpa  avg_temp_c_3  precipitation_mm_3  \
# date
# 2021-01-04  Winter                  1011.3           5.1                 0.0
# 2021-01-05  Winter                  1014.5           3.0                 0.0
# 2021-01-06  Winter                  1017.2           6.8                 1.3
# 2021-01-07  Winter                  1015.2           6.6                 3.6
# 2021-01-08  Winter                  1009.7           4.3                 4.6
# ...            ...                     ...           ...                 ...
# 2023-07-28  Summer                  1014.6          29.2                 0.0
# 2023-07-29  Summer                  1011.7          28.2                 0.0
# 2023-07-30  Summer                  1009.8          20.7                 0.0
# 2023-07-31  Summer                  1010.9          22.8                 0.0
# 2023-08-01  Summer                  1008.7          26.3                 0.0
#
#             avg_wind_dir_deg_3  avg_wind_speed_kmh_3  \
# date
# 2021-01-04               330.0                   5.9
# 2021-01-05               330.0                   5.9
# 2021-01-06               339.0                   8.0
# 2021-01-07               298.0                   5.3
# 2021-01-08                11.0                   5.1
# ...                        ...                   ...
# 2023-07-28               275.0                   4.7
# 2023-07-29               242.0                  13.4
# 2023-07-30               316.0                  16.0
# 2023-07-31                 2.0                   6.8
# 2023-08-01               261.0                   6.2
#
#             avg_sea_level_pres_hpa_3  avg_temp_c_2  precipitation_mm_2  \
# date
# 2021-01-04                    1021.2           3.0                 0.0
# 2021-01-05                    1021.2           6.8                 1.3
# 2021-01-06                    1017.8           6.6                 3.6
# 2021-01-07                    1011.3           4.3                 4.6
# 2021-01-08                    1014.5           6.2                 0.0
# ...                              ...           ...                 ...
# 2023-07-28                    1007.7          28.2                 0.0
# 2023-07-29                    1002.9          20.7                 0.0
# 2023-07-30                    1012.6          22.8                 0.0
# 2023-07-31                    1014.6          26.3                 0.0
# 2023-08-01                    1011.7          28.2                 0.0
#
#             avg_wind_dir_deg_2  ...  Summer  Winter  Autumn  Spring  Summer  \
# date                            ...
# 2021-01-04               330.0  ...       0       1       0       0       0
# 2021-01-05               339.0  ...       0       1       0       0       0
# 2021-01-06               298.0  ...       0       1       0       0       0
# 2021-01-07                11.0  ...       0       1       0       0       0
# 2021-01-08                18.0  ...       0       1       0       0       0
# ...                        ...  ...     ...     ...     ...     ...     ...
# 2023-07-28               242.0  ...       1       0       0       0       1
# 2023-07-29               316.0  ...       1       0       0       0       1
# 2023-07-30                 2.0  ...       1       0       0       0       1
# 2023-07-31               261.0  ...       1       0       0       0       1
# 2023-08-01               317.0  ...       1       0       0       0       1
#
#             Winter  Autumn  Spring  Summer  Winter
# date
# 2021-01-04       1       0       0       0       1
# 2021-01-05       1       0       0       0       1
# 2021-01-06       1       0       0       0       1
# 2021-01-07       1       0       0       0       1
# 2021-01-08       1       0       0       0       1
# ...            ...     ...     ...     ...     ...
# 2023-07-28       0       0       0       1       0
# 2023-07-29       0       0       0       1       0
# 2023-07-30       0       0       0       1       0
# 2023-07-31       0       0       0       1       0
# 2023-08-01       0       0       0       1       0
#
# [940 rows x 33 columns]

# %%
df_7 = df_6.drop(columns="season")

# %%
df_7
# Out:
#             avg_sea_level_pres_hpa  avg_temp_c_3  precipitation_mm_3  \
# date
# 2021-01-04                  1011.3           5.1                 0.0
# 2021-01-05                  1014.5           3.0                 0.0
# 2021-01-06                  1017.2           6.8                 1.3
# 2021-01-07                  1015.2           6.6                 3.6
# 2021-01-08                  1009.7           4.3                 4.6
# ...                            ...           ...                 ...
# 2023-07-28                  1014.6          29.2                 0.0
# 2023-07-29                  1011.7          28.2                 0.0
# 2023-07-30                  1009.8          20.7                 0.0
# 2023-07-31                  1010.9          22.8                 0.0
# 2023-08-01                  1008.7          26.3                 0.0
#
#             avg_wind_dir_deg_3  avg_wind_speed_kmh_3  \
# date
# 2021-01-04               330.0                   5.9
# 2021-01-05               330.0                   5.9
# 2021-01-06               339.0                   8.0
# 2021-01-07               298.0                   5.3
# 2021-01-08                11.0                   5.1
# ...                        ...                   ...
# 2023-07-28               275.0                   4.7
# 2023-07-29               242.0                  13.4
# 2023-07-30               316.0                  16.0
# 2023-07-31                 2.0                   6.8
# 2023-08-01               261.0                   6.2
#
#             avg_sea_level_pres_hpa_3  avg_temp_c_2  precipitation_mm_2  \
# date
# 2021-01-04                    1021.2           3.0                 0.0
# 2021-01-05                    1021.2           6.8                 1.3
# 2021-01-06                    1017.8           6.6                 3.6
# 2021-01-07                    1011.3           4.3                 4.6
# 2021-01-08                    1014.5           6.2                 0.0
# ...                              ...           ...                 ...
# 2023-07-28                    1007.7          28.2                 0.0
# 2023-07-29                    1002.9          20.7                 0.0
# 2023-07-30                    1012.6          22.8                 0.0
# 2023-07-31                    1014.6          26.3                 0.0
# 2023-08-01                    1011.7          28.2                 0.0
#
#             avg_wind_dir_deg_2  avg_wind_speed_kmh_2  ...  Summer  Winter  \
# date                                                  ...
# 2021-01-04               330.0                   5.9  ...       0       1
# 2021-01-05               339.0                   8.0  ...       0       1
# 2021-01-06               298.0                   5.3  ...       0       1
# 2021-01-07                11.0                   5.1  ...       0       1
# 2021-01-08                18.0                   6.7  ...       0       1
# ...                        ...                   ...  ...     ...     ...
# 2023-07-28               242.0                  13.4  ...       1       0
# 2023-07-29               316.0                  16.0  ...       1       0
# 2023-07-30                 2.0                   6.8  ...       1       0
# 2023-07-31               261.0                   6.2  ...       1       0
# 2023-08-01               317.0                   8.0  ...       1       0
#
#             Autumn  Spring  Summer  Winter  Autumn  Spring  Summer  Winter
# date
# 2021-01-04       0       0       0       1       0       0       0       1
# 2021-01-05       0       0       0       1       0       0       0       1
# 2021-01-06       0       0       0       1       0       0       0       1
# 2021-01-07       0       0       0       1       0       0       0       1
# 2021-01-08       0       0       0       1       0       0       0       1
# ...            ...     ...     ...     ...     ...     ...     ...     ...
# 2023-07-28       0       0       1       0       0       0       1       0
# 2023-07-29       0       0       1       0       0       0       1       0
# 2023-07-30       0       0       1       0       0       0       1       0
# 2023-07-31       0       0       1       0       0       0       1       0
# 2023-08-01       0       0       1       0       0       0       1       0
#
# [940 rows x 32 columns]

# %%
x,y = get_x_and_y(df_7,target_column=target)

# %% [markdown]
# Explore the dataset using visualizations of your choice.

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# Remove the highly correlated features.

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# Encode the categorical features.

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# # Feauture Extraction
# Select the relevant features for prediction and apply a lag of one, two, and three days to each chosen feature (except `season`), creating a set of features representing the meteorological conditions from the previous three days. To maintain dataset integrity, eliminate any resulting missing values at the beginning of the dataset.
#
# Hint: Use `df['column_name'].shift(period)`. Check the documentation at https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shift.html.

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# ## Dataset Splitting
# Partition the dataset into training and testing sets with an 80:20 ratio.
#
# **WARNING: DO NOT SHUFFLE THE DATASET.**

# %%
# Write your code here. Add as many boxes as you need.
x_train,x_test,y_train, y_test = train_test_split(x, y, test_size= 0.2, shuffle=False)

# %%
x_train
# Out:
#             avg_temp_c_3  precipitation_mm_3  avg_wind_dir_deg_3  \
# date
# 2021-01-04           5.1                 0.0               330.0
# 2021-01-05           3.0                 0.0               330.0
# 2021-01-06           6.8                 1.3               339.0
# 2021-01-07           6.6                 3.6               298.0
# 2021-01-08           4.3                 4.6                11.0
# ...                  ...                 ...                 ...
# 2023-01-21          12.6                 0.0               143.0
# 2023-01-22          12.5                 9.0                96.0
# 2023-01-23           7.4                 1.0                91.0
# 2023-01-24           4.3                 0.5               264.0
# 2023-01-25           5.8                 0.0               261.0
#
#             avg_wind_speed_kmh_3  avg_sea_level_pres_hpa_3  avg_temp_c_2  \
# date
# 2021-01-04                   5.9                    1021.2           3.0
# 2021-01-05                   5.9                    1021.2           6.8
# 2021-01-06                   8.0                    1017.8           6.6
# 2021-01-07                   5.3                    1011.3           4.3
# 2021-01-08                   5.1                    1014.5           6.2
# ...                          ...                       ...           ...
# 2023-01-21                   9.1                    1002.8          12.5
# 2023-01-22                  12.5                    1004.7           7.4
# 2023-01-23                   8.5                    1005.4           4.3
# 2023-01-24                   8.4                    1010.5           5.8
# 2023-01-25                   5.9                    1019.0           8.3
#
#             precipitation_mm_2  avg_wind_dir_deg_2  avg_wind_speed_kmh_2  \
# date
# 2021-01-04                 0.0               330.0                   5.9
# 2021-01-05                 1.3               339.0                   8.0
# 2021-01-06                 3.6               298.0                   5.3
# 2021-01-07                 4.6                11.0                   5.1
# 2021-01-08                 0.0                18.0                   6.7
# ...                        ...                 ...                   ...
# 2023-01-21                 9.0                96.0                  12.5
# 2023-01-22                 1.0                91.0                   8.5
# 2023-01-23                 0.5               264.0                   8.4
# 2023-01-24                 0.0               261.0                   5.9
# 2023-01-25                 0.0               139.0                   7.8
#
#             avg_sea_level_pres_hpa_2  ...  Summer  Winter  Autumn  Spring  \
# date                                  ...
# 2021-01-04                    1021.2  ...       0       1       0       0
# 2021-01-05                    1017.8  ...       0       1       0       0
# 2021-01-06                    1011.3  ...       0       1       0       0
# 2021-01-07                    1014.5  ...       0       1       0       0
# 2021-01-08                    1017.2  ...       0       1       0       0
# ...                              ...  ...     ...     ...     ...     ...
# 2023-01-21                    1004.7  ...       0       1       0       0
# 2023-01-22                    1005.4  ...       0       1       0       0
# 2023-01-23                    1010.5  ...       0       1       0       0
# 2023-01-24                    1019.0  ...       0       1       0       0
# 2023-01-25                    1021.6  ...       0       1       0       0
#
#             Summer  Winter  Autumn  Spring  Summer  Winter
# date
# 2021-01-04       0       1       0       0       0       1
# 2021-01-05       0       1       0       0       0       1
# 2021-01-06       0       1       0       0       0       1
# 2021-01-07       0       1       0       0       0       1
# 2021-01-08       0       1       0       0       0       1
# ...            ...     ...     ...     ...     ...     ...
# 2023-01-21       0       1       0       0       0       1
# 2023-01-22       0       1       0       0       0       1
# 2023-01-23       0       1       0       0       0       1
# 2023-01-24       0       1       0       0       0       1
# 2023-01-25       0       1       0       0       0       1
#
# [752 rows x 31 columns]

# %%
lag = 3

# %%
scaler = MinMaxScaler()

# %%
x_train_scaled = scaler.fit_transform(x_train)

# %%
x_test_scaled = scaler.transform(x_test)

# %%
y_scaler = MinMaxScaler()

# %%
y_train_scaled = y_scaler.fit_transform(y_train.to_numpy().reshape(-1,1))

# %%
x_train_scaled
# Out:
# array([[0.29015544, 0.        , 0.91922006, ..., 0.        , 0.        ,
#         1.        ],
#        [0.2357513 , 0.        , 0.91922006, ..., 0.        , 0.        ,
#         1.        ],
#        [0.33419689, 0.03299492, 0.94428969, ..., 0.        , 0.        ,
#         1.        ],
#        ...,
#        [0.34974093, 0.02538071, 0.25348189, ..., 0.        , 0.        ,
#         1.        ],
#        [0.26943005, 0.01269036, 0.73537604, ..., 0.        , 0.        ,
#         1.        ],
#        [0.30829016, 0.        , 0.7270195 , ..., 0.        , 0.        ,
#         1.        ]])

# %%
x_test_scaled
# Out:
# array([[0.37305699, 0.        , 0.38718663, ..., 0.        , 0.        ,
#         1.        ],
#        [0.32124352, 0.01269036, 0.70752089, ..., 0.        , 0.        ,
#         1.        ],
#        [0.27979275, 0.00761421, 0.13649025, ..., 0.        , 0.        ,
#         1.        ],
#        ...,
#        [0.69430052, 0.        , 0.88022284, ..., 0.        , 1.        ,
#         0.        ],
#        [0.74870466, 0.        , 0.00557103, ..., 0.        , 1.        ,
#         0.        ],
#        [0.83937824, 0.        , 0.7270195 , ..., 0.        , 1.        ,
#         0.        ]])

# %%
x_train_scaled.shape
# Out:
# (752, 31)

# %%
x_train_scaled_shaped = x_train_scaled.reshape(x_train_scaled.shape[0], lag, (x_train_scaled.shape[1] // lag))
# x_test_scaled_shaped = x_test_scaled.reshape(x_test_scaled.shape[0], lag, (x_test_scaled.shape[1] // lag))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 x_train_scaled_shaped = x_train_scaled.reshape(x_train_scaled.shape[0], lag, (x_train_scaled.shape[1] // lag))
#       2 # x_test_scaled_shaped = x_test_scaled.reshape(x_test_scaled.shape[0], lag, (x_test_scaled.shape[1] // lag))
#
# ValueError: cannot reshape array of size 23312 into shape (752,3,10)

# %%
from keras.api.models import Sequential
from keras.api.layers import Input, LSTM, Dense

# %%
model = Sequential([
    Input((x_train_scaled_shaped.shape[1], x_train_scaled_shaped.shape[2],)),
    LSTM(64, activation="relu", return_sequences=True),
    LSTM(32, activation="relu", return_sequences=False),
    Dense(1, activation="linear")
])

# %%
model.summary()
# Out:
# Model: "sequential_7"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_15 (LSTM)                  │ (None, 3, 64)          │        17,920 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_16 (LSTM)                  │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30,369 (118.63 KB)
#  Trainable params: 30,369 (118.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
x_train_scaled_shaped.shape
# Out:
# (752, 3, 5)

# %%
model.compile(
    loss="mean_squared_error",
    optimizer="adam",
    metrics=["mean_squared_error"],
)

# %%
history = model.fit(x_train_scaled_shaped, y_train_scaled, validation_split=0.2, epochs=32, batch_size=32, shuffle=False)
# Out:
# Epoch 1/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 3s 26ms/step - loss: 0.2411 - mean_squared_error: 0.2411 - val_loss: 0.1855 - val_mean_squared_error: 0.1855
# Epoch 2/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.1057 - mean_squared_error: 0.1057 - val_loss: 0.0377 - val_mean_squared_error: 0.0377
# Epoch 3/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0329 - mean_squared_error: 0.0329 - val_loss: 0.0393 - val_mean_squared_error: 0.0393
# Epoch 4/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0272 - mean_squared_error: 0.0272 - val_loss: 0.0346 - val_mean_squared_error: 0.0346
# Epoch 5/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0250 - mean_squared_error: 0.0250 - val_loss: 0.0330 - val_mean_squared_error: 0.0330
# Epoch 6/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0232 - mean_squared_error: 0.0232 - val_loss: 0.0311 - val_mean_squared_error: 0.0311
# Epoch 7/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0220 - mean_squared_error: 0.0220 - val_loss: 0.0299 - val_mean_squared_error: 0.0299
# Epoch 8/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - loss: 0.0211 - mean_squared_error: 0.0211 - val_loss: 0.0286 - val_mean_squared_error: 0.0286
# Epoch 9/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0204 - mean_squared_error: 0.0204 - val_loss: 0.0278 - val_mean_squared_error: 0.0278
# Epoch 10/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0200 - mean_squared_error: 0.0200 - val_loss: 0.0272 - val_mean_squared_error: 0.0272
# Epoch 11/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0196 - mean_squared_error: 0.0196 - val_loss: 0.0268 - val_mean_squared_error: 0.0268
# Epoch 12/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0193 - mean_squared_error: 0.0193 - val_loss: 0.0264 - val_mean_squared_error: 0.0264
# Epoch 13/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0191 - mean_squared_error: 0.0191 - val_loss: 0.0260 - val_mean_squared_error: 0.0260
# Epoch 14/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0189 - mean_squared_error: 0.0189 - val_loss: 0.0256 - val_mean_squared_error: 0.0256
# Epoch 15/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0187 - mean_squared_error: 0.0187 - val_loss: 0.0254 - val_mean_squared_error: 0.0254
# Epoch 16/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0186 - mean_squared_error: 0.0186 - val_loss: 0.0251 - val_mean_squared_error: 0.0251
# Epoch 17/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0249 - val_mean_squared_error: 0.0249
# Epoch 18/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0183 - mean_squared_error: 0.0183 - val_loss: 0.0247 - val_mean_squared_error: 0.0247
# Epoch 19/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - loss: 0.0181 - mean_squared_error: 0.0181 - val_loss: 0.0245 - val_mean_squared_error: 0.0245
# Epoch 20/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - loss: 0.0180 - mean_squared_error: 0.0180 - val_loss: 0.0243 - val_mean_squared_error: 0.0243
# Epoch 21/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0178 - mean_squared_error: 0.0178 - val_loss: 0.0241 - val_mean_squared_error: 0.0241
# Epoch 22/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0177 - mean_squared_error: 0.0177 - val_loss: 0.0239 - val_mean_squared_error: 0.0239
# Epoch 23/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0175 - mean_squared_error: 0.0175 - val_loss: 0.0236 - val_mean_squared_error: 0.0236
# Epoch 24/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - loss: 0.0173 - mean_squared_error: 0.0173 - val_loss: 0.0232 - val_mean_squared_error: 0.0232
# Epoch 25/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - loss: 0.0169 - mean_squared_error: 0.0169 - val_loss: 0.0229 - val_mean_squared_error: 0.0229
# Epoch 26/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0167 - mean_squared_error: 0.0167 - val_loss: 0.0227 - val_mean_squared_error: 0.0227
# Epoch 27/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0166 - mean_squared_error: 0.0166 - val_loss: 0.0225 - val_mean_squared_error: 0.0225
# Epoch 28/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0165 - mean_squared_error: 0.0165 - val_loss: 0.0222 - val_mean_squared_error: 0.0222
# Epoch 29/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0163 - mean_squared_error: 0.0163 - val_loss: 0.0219 - val_mean_squared_error: 0.0219
# Epoch 30/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0160 - mean_squared_error: 0.0160 - val_loss: 0.0216 - val_mean_squared_error: 0.0216
# Epoch 31/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0157 - mean_squared_error: 0.0157 - val_loss: 0.0213 - val_mean_squared_error: 0.0213
# Epoch 32/32
# 19/19 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - loss: 0.0155 - mean_squared_error: 0.0155 - val_loss: 0.0210 - val_mean_squared_error: 0.0210

# %%
sns.lineplot(history.history["loss"], label="loss")
sns.lineplot(history.history["val_loss"], label="val_loss")
# Out:
# <Axes: >

# %%
pred_y = model.predict(x_test_scaled_shaped)
# Out:
# 6/6 ━━━━━━━━━━━━━━━━━━━━ 0s 41ms/step

# %%
pred_y = y_scaler.inverse_transform(pred_y)
r2_score(y_test, pred_y)
# Out:
# 0.5754501313259941

# %%
xgb_regressor = XGBRegressor()

# %%
xgb_regressor.fit(x_train_scaled, y_train_scaled)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=None, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=None, n_jobs=None,
#              num_parallel_tree=None, random_state=None, ...)

# %% [markdown]
# ## Ensemble Learning Methods

# %%
pred_y_xg = xgb_regressor.predict(x_test_scaled)

# %%
pred_y_xg
# Out:
# array([0.58950365, 0.3624792 , 0.3921534 , 0.52624136, 0.72503936,
#        0.45313781, 0.53844124, 0.61720246, 0.42236817, 0.6847432 ,
#        0.454     , 0.77360755, 0.80195254, 0.7839121 , 0.8146454 ,
#        0.8530498 , 0.82394177, 0.8324546 , 0.81112117, 0.72242326,
#        0.8578416 , 0.72187775, 0.81726134, 0.7340156 , 0.62484974,
#        0.4419601 , 0.68521225, 0.4563834 , 0.4418499 , 0.43845108,
#        0.35630146, 0.21663745, 0.1821177 , 0.5983949 , 0.5767933 ,
#        0.51510555, 0.4504092 , 0.42338422, 0.4221842 , 0.43784782,
#        0.40032348, 0.34824082, 0.44543418, 0.20634657, 0.17797756,
#        0.2502434 , 0.5826669 , 0.66152763, 0.34108672, 0.21911672,
#        0.52160054, 0.6018797 , 0.4671018 , 0.5899585 , 0.47296843,
#        0.3762724 , 0.48499683, 0.49002144, 0.3852145 , 0.4263804 ,
#        0.21682641, 0.30736998, 0.60694605, 0.6970887 , 0.6007949 ,
#        0.33890224, 0.19232653, 0.4409926 , 0.3424846 , 0.49450454,
#        0.48704687, 0.45767426, 0.5844668 , 0.5225719 , 0.566329  ,
#        0.5303684 , 0.41074067, 0.42964873, 0.31501496, 0.16940477,
#        0.3111992 , 0.43121096, 0.40692085, 0.25600693, 0.47822165,
#        0.45171627, 0.39755738, 0.44796106, 0.44599077, 0.32735315,
#        0.27391362, 0.40826604, 0.5989584 , 0.53810835, 0.46091282,
#        0.42495528, 0.5180357 , 0.5664084 , 0.5473507 , 0.51460767,
#        0.54508173, 0.42865217, 0.43237522, 0.5742298 , 0.5578766 ,
#        0.50000936, 0.55145735, 0.5737336 , 0.58840525, 0.438207  ,
#        0.36391813, 0.42250744, 0.37703043, 0.44017038, 0.53604764,
#        0.4006519 , 0.37950975, 0.4122742 , 0.4156679 , 0.38429165,
#        0.4725762 , 0.48191473, 0.43114722, 0.41280863, 0.41756272,
#        0.39137337, 0.45214033, 0.38866147, 0.34980842, 0.4294276 ,
#        0.48588583, 0.5211631 , 0.50871104, 0.46274602, 0.4003075 ,
#        0.4020685 , 0.3539963 , 0.37548083, 0.3295895 , 0.4133053 ,
#        0.41061884, 0.41035324, 0.34074268, 0.41916758, 0.46189293,
#        0.45928794, 0.45478705, 0.45490986, 0.45264545, 0.3367099 ,
#        0.41745076, 0.3729636 , 0.36309052, 0.37316585, 0.3860366 ,
#        0.46286064, 0.37648028, 0.31277573, 0.34193262, 0.4098461 ,
#        0.3803937 , 0.31626266, 0.3759102 , 0.46867523, 0.53928   ,
#        0.48303762, 0.5039959 , 0.45641756, 0.43256012, 0.41595846,
#        0.37918764, 0.41463733, 0.38782072, 0.45905912, 0.44218248,
#        0.4065845 , 0.34000328, 0.3231265 , 0.3754635 , 0.42036238,
#        0.371744  , 0.25335932, 0.2851878 , 0.4791804 , 0.41779333,
#        0.36202887, 0.35355493, 0.37697878], dtype=float32)

# %%
pred_y_xg_1 = y_scaler.inverse_transform(pred_y_xg.reshape(-1,1))
r2_score(y_test, pred_y_xg_1)
# Out:
# 0.6873367985565233

# %% [markdown]
# ### Bagging

# %% [markdown]
# Create an instance of a Random Forest model and train it using the `fit` function.

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# Use the trained model to make predictions for the test set.

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# Assess the performance of the model by using different metrics provided by the `scikit-learn` library.

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# ### Boosting

# %% [markdown]
# Create an instance of an XGBoost model and train it using the `fit` function.

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# Use the trained model to make predictions for the test set.

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# Assess the performance of the model by using different metrics provided by the `scikit-learn` library.

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# # Laboratory Exercise - Bonus Task (+ 2 points)

# %% [markdown]
# As part of the bonus task in this laboratory assignment, your objective is to fine-tune the max_depth (`max_depth`) for the Random Forest model using a cross-validation with grid search and time series split. This involves systematically experimenting with various values for `max_depth` and evaluating the model's performance using cross-validation. Upon determining the most suitable `max_depth` value, evaluate the model's performance on a test set for final assessment.
#
# Hints:
# - For grid search use the `GridCVSearch` from the `scikit-learn` library. Check the documentation at https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html.
# - For cross-validation use the `TimeSeriesSplit` from the `scikit-learn` library. Check the documentation at https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html.

# %% [markdown]
# ## Dataset Splitting
# Partition the dataset into training and testing sets with an 90:10 ratio.
#
# **WARNING: DO NOT SHUFFLE THE DATASET.**

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# ## Fine-tuning the Random Forest Hyperparameter
# Experiment with various values for `max_depth` and evaluate the model's performance using cross-validation.

# %%
# Write your code here. Add as many boxes as you need.

# %% [markdown]
# ## Final Assessment of the Model Performance
# Upon determining the most suitable `max_depth` value, evaluate the model's performance on a test set for final assessment.

# %%
# Write your code here. Add as many boxes as you need.
