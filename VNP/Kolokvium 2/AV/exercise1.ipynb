# %% [markdown]
# ![image](screenshot.png)

# %% [markdown]
# # Time-series Forecasting
#
# ## Description
# The data consists of 52,416 observations of energy consumption on a 10-minute window. Every observation is described by the following feature columns.
#
# Your task is to **aggregate the observations on an interval of 30 minutes**. For this time interval, using the values of the **5 previous time intervals**, forecast the target value one step in the future. Choose which features you are going to use.
#
# **You must train an LSTM network.**
#
#
#
# Features:
#
# * Datetime: Time window of ten minutes.
# * Temperature: Weather Temperature.
# * Humidity: Weather Humidity.
# * WindSpeed: Wind Speed.
# * GeneralDiffuseFlows: “Diffuse flow” is a catchall term to describe low-temperature (< 0.2° to ~ 100°C) fluids that slowly discharge through sulfide mounds, fractured lava flows, and assemblages of bacterial mats and macrofauna.
# * DiffuseFlows
#
# Target:
#
# PowerConsumption
#
# ## Dataset links:
#  * [DS1](https://drive.google.com/file/d/1k5Ee9kla-0s8iuEASsSY2u5hl6YstzlN/view?usp=sharing)
#  * [DS2](https://drive.google.com/file/d/1--Kep6SOWuyQ2FTlBDdwWHj-65bOl1kc/view?usp=sharing)

# %% [markdown]
# ## Read the datasets

# %%
import pandas as pd

# %%
features_df = pd.read_csv("../data/power_consumption_g1_feat.csv")
features_df
# Out:
#                   Datetime  Temperature  Humidity  WindSpeed  \
# 0      2017-03-01 16:40:00        21.33     55.91      0.080
# 1      2017-07-27 06:30:00        23.10     48.58      4.908
# 2      2017-10-11 19:00:00        23.10     59.82      0.084
# 3      2017-02-10 06:50:00        12.25     80.80      4.916
# 4      2017-03-06 16:00:00        15.62     59.38      0.075
# ...                    ...          ...       ...        ...
# 52411  2017-05-14 02:20:00        23.58     43.10      0.075
# 52412  2017-11-17 19:20:00        17.30     76.50      0.075
# 52413  2017-03-21 12:10:00        17.90     50.28      0.081
# 52414  2017-07-28 05:10:00        25.23     61.32      4.907
# 52415  2017-12-16 20:30:00        13.90     80.80      0.082
#
#        GeneralDiffuseFlows  DiffuseFlows
# 0                  387.400       427.300
# 1                   10.450         8.630
# 2                    0.446         0.322
# 3                    0.051         0.111
# 4                  533.400       579.900
# ...                    ...           ...
# 52411                0.110         0.122
# 52412                0.040         0.148
# 52413              837.000       296.700
# 52414                0.091         0.119
# 52415                0.051         0.152
#
# [52416 rows x 6 columns]

# %%
features_df["Datetime"] = pd.to_datetime(features_df["Datetime"])
features_df.set_index(keys=["Datetime"], inplace=True)
features_df.sort_index(inplace=True)
features_df
# Out:
#                      Temperature  Humidity  WindSpeed  GeneralDiffuseFlows  \
# Datetime
# 2017-01-01 00:00:00        6.559      73.8      0.083                0.051
# 2017-01-01 00:10:00        6.414      74.5      0.083                0.070
# 2017-01-01 00:20:00        6.313      74.5      0.080                0.062
# 2017-01-01 00:30:00        6.121      75.0      0.083                0.091
# 2017-01-01 00:40:00        5.921      75.7      0.081                0.048
# ...                          ...       ...        ...                  ...
# 2017-12-30 23:10:00        7.010      72.4      0.080                  NaN
# 2017-12-30 23:20:00        6.947      72.6      0.082                0.051
# 2017-12-30 23:30:00        6.900      72.8      0.086                0.084
# 2017-12-30 23:40:00        6.758      73.0      0.080                0.066
# 2017-12-30 23:50:00        6.580      74.1      0.081                0.062
#
#                      DiffuseFlows
# Datetime
# 2017-01-01 00:00:00         0.119
# 2017-01-01 00:10:00         0.085
# 2017-01-01 00:20:00         0.100
# 2017-01-01 00:30:00         0.096
# 2017-01-01 00:40:00         0.085
# ...                           ...
# 2017-12-30 23:10:00         0.096
# 2017-12-30 23:20:00         0.093
# 2017-12-30 23:30:00         0.074
# 2017-12-30 23:40:00         0.089
# 2017-12-30 23:50:00         0.111
#
# [52416 rows x 5 columns]

# %%
target_df = pd.read_csv("../data/power_consumption_g1.csv")
target_df
# Out:
#                   Datetime  PowerConsumption
# 0      2017-10-04 02:20:00       26802.27571
# 1      2017-05-28 13:20:00       32898.09836
# 2      2017-03-15 06:00:00       22304.68085
# 3      2017-10-31 11:40:00       32316.49891
# 4      2017-04-20 02:50:00       23982.43272
# ...                    ...               ...
# 52411  2017-05-27 13:30:00       35000.65574
# 52412  2017-10-29 20:10:00       39425.12035
# 52413  2017-02-05 16:10:00       28751.18644
# 52414  2017-04-11 17:20:00       32098.51453
# 52415  2017-03-26 05:20:00       22365.95745
#
# [52416 rows x 2 columns]

# %%
target_df["Datetime"] = pd.to_datetime(target_df["Datetime"])
target_df.set_index(keys=["Datetime"], inplace=True)
target_df.sort_index(inplace=True)
target_df
# Out:
#                      PowerConsumption
# Datetime
# 2017-01-01 00:00:00       34055.69620
# 2017-01-01 00:10:00       29814.68354
# 2017-01-01 00:20:00       29128.10127
# 2017-01-01 00:30:00       28228.86076
# 2017-01-01 00:40:00       27335.69620
# ...                               ...
# 2017-12-30 23:10:00       31160.45627
# 2017-12-30 23:20:00       30430.41825
# 2017-12-30 23:30:00       29590.87452
# 2017-12-30 23:40:00       28958.17490
# 2017-12-30 23:50:00       28349.80989
#
# [52416 rows x 1 columns]

# %% [markdown]
# ## Merge the datasets (and pre-processing if needed)

# %%
df = pd.merge(left=features_df, right=target_df, right_index=True, left_index=True)
df
# Out:
#                      Temperature  Humidity  WindSpeed  GeneralDiffuseFlows  \
# Datetime
# 2017-01-01 00:00:00        6.559      73.8      0.083                0.051
# 2017-01-01 00:10:00        6.414      74.5      0.083                0.070
# 2017-01-01 00:20:00        6.313      74.5      0.080                0.062
# 2017-01-01 00:30:00        6.121      75.0      0.083                0.091
# 2017-01-01 00:40:00        5.921      75.7      0.081                0.048
# ...                          ...       ...        ...                  ...
# 2017-12-30 23:10:00        7.010      72.4      0.080                  NaN
# 2017-12-30 23:20:00        6.947      72.6      0.082                0.051
# 2017-12-30 23:30:00        6.900      72.8      0.086                0.084
# 2017-12-30 23:40:00        6.758      73.0      0.080                0.066
# 2017-12-30 23:50:00        6.580      74.1      0.081                0.062
#
#                      DiffuseFlows  PowerConsumption
# Datetime
# 2017-01-01 00:00:00         0.119       34055.69620
# 2017-01-01 00:10:00         0.085       29814.68354
# 2017-01-01 00:20:00         0.100       29128.10127
# 2017-01-01 00:30:00         0.096       28228.86076
# 2017-01-01 00:40:00         0.085       27335.69620
# ...                           ...               ...
# 2017-12-30 23:10:00         0.096       31160.45627
# 2017-12-30 23:20:00         0.093       30430.41825
# 2017-12-30 23:30:00         0.074       29590.87452
# 2017-12-30 23:40:00         0.089       28958.17490
# 2017-12-30 23:50:00         0.111       28349.80989
#
# [52416 rows x 6 columns]

# %%
df.isnull().sum()
# Out:
# Temperature            559
# Humidity               499
# WindSpeed              529
# GeneralDiffuseFlows    524
# DiffuseFlows           505
# PowerConsumption         0
# dtype: int64

# %%
features = ["Temperature", "Humidity", "WindSpeed", "GeneralDiffuseFlows", "DiffuseFlows"]
target = "PowerConsumption"

# %%
for feature in features:
    df[feature] = df[feature].interpolate(method="linear")

# %%
df.isnull().sum()
# Out:
# Temperature            0
# Humidity               0
# WindSpeed              0
# GeneralDiffuseFlows    0
# DiffuseFlows           0
# PowerConsumption       0
# dtype: int64

# %% [markdown]
# ## Group the datasets into time intervals of 30 mintues

# %%
df = df.groupby(pd.Grouper(freq="30min")).mean()
df
# Out:
#                      Temperature   Humidity  WindSpeed  GeneralDiffuseFlows  \
# Datetime
# 2017-01-01 00:00:00     6.428667  74.266667   0.082000             0.061000
# 2017-01-01 00:30:00     5.941000  75.866667   0.081667             0.066000
# 2017-01-01 01:00:00     5.605000  77.900000   0.082000             0.056333
# 2017-01-01 01:30:00     5.492667  77.166667   0.082000             0.057333
# 2017-01-01 02:00:00     5.000667  78.766667   0.082667             0.065000
# ...                          ...        ...        ...                  ...
# 2017-12-30 21:30:00     7.913333  70.343333   0.081667             0.069333
# 2017-12-30 22:00:00     7.793333  69.563333   0.081000             0.062333
# 2017-12-30 22:30:00     7.403333  71.066667   0.082667             0.055000
# 2017-12-30 23:00:00     7.009000  72.500000   0.080667             0.055000
# 2017-12-30 23:30:00     6.746000  73.300000   0.082333             0.070667
#
#                      DiffuseFlows  PowerConsumption
# Datetime
# 2017-01-01 00:00:00      0.101333      30999.493670
# 2017-01-01 00:30:00      0.096333      27396.455697
# 2017-01-01 01:00:00      0.110000      25407.594937
# 2017-01-01 01:30:00      0.115000      23906.835443
# 2017-01-01 02:00:00      0.127333      22474.936707
# ...                           ...               ...
# 2017-12-30 21:30:00      0.087667      34786.311787
# 2017-12-30 22:00:00      0.108667      34660.583017
# 2017-12-30 22:30:00      0.107667      33326.235743
# 2017-12-30 23:00:00      0.094000      31249.683140
# 2017-12-30 23:30:00      0.091333      28966.286437
#
# [17472 rows x 6 columns]

# %%
import seaborn as sns

# %%
sns.lineplot(df["Temperature"])
# Out:
# <Axes: xlabel='Datetime', ylabel='Temperature'>

# %%
sns.lineplot(df["Humidity"])
# Out:
# <Axes: xlabel='Datetime', ylabel='Humidity'>

# %%
sns.lineplot(df["WindSpeed"])
# Out:
# <Axes: xlabel='Datetime', ylabel='WindSpeed'>

# %%
sns.lineplot(df["GeneralDiffuseFlows"])
# Out:
# <Axes: xlabel='Datetime', ylabel='GeneralDiffuseFlows'>

# %%
sns.lineplot(df["DiffuseFlows"])
# Out:
# <Axes: xlabel='Datetime', ylabel='DiffuseFlows'>

# %%
sns.heatmap(df.corr(), annot=True, fmt=".2f")
# Out:
# <Axes: >

# %%
sns.pairplot(df)

# %% [markdown]
# ## Create lags

# %%
lags = range(5, 0, -1)
list(lags)
# Out:
# [5, 4, 3, 2, 1]

# %%
# df = df.shift(periods=lags)
# df

# %%
for lag in lags:
    for column in features + [target]:
        df[f"{column}_{lag}"] = df[column].shift(lag)
df
# Out:
#                      Temperature   Humidity  WindSpeed  GeneralDiffuseFlows  \
# Datetime
# 2017-01-01 00:00:00     6.428667  74.266667   0.082000             0.061000
# 2017-01-01 00:30:00     5.941000  75.866667   0.081667             0.066000
# 2017-01-01 01:00:00     5.605000  77.900000   0.082000             0.056333
# 2017-01-01 01:30:00     5.492667  77.166667   0.082000             0.057333
# 2017-01-01 02:00:00     5.000667  78.766667   0.082667             0.065000
# ...                          ...        ...        ...                  ...
# 2017-12-30 21:30:00     7.913333  70.343333   0.081667             0.069333
# 2017-12-30 22:00:00     7.793333  69.563333   0.081000             0.062333
# 2017-12-30 22:30:00     7.403333  71.066667   0.082667             0.055000
# 2017-12-30 23:00:00     7.009000  72.500000   0.080667             0.055000
# 2017-12-30 23:30:00     6.746000  73.300000   0.082333             0.070667
#
#                      DiffuseFlows  PowerConsumption  Temperature_5  \
# Datetime
# 2017-01-01 00:00:00      0.101333      30999.493670            NaN
# 2017-01-01 00:30:00      0.096333      27396.455697            NaN
# 2017-01-01 01:00:00      0.110000      25407.594937            NaN
# 2017-01-01 01:30:00      0.115000      23906.835443            NaN
# 2017-01-01 02:00:00      0.127333      22474.936707            NaN
# ...                           ...               ...            ...
# 2017-12-30 21:30:00      0.087667      34786.311787       9.710000
# 2017-12-30 22:00:00      0.108667      34660.583017       9.196667
# 2017-12-30 22:30:00      0.107667      33326.235743       8.933333
# 2017-12-30 23:00:00      0.094000      31249.683140       9.150000
# 2017-12-30 23:30:00      0.091333      28966.286437       8.110000
#
#                      Humidity_5  WindSpeed_5  GeneralDiffuseFlows_5  ...  \
# Datetime                                                             ...
# 2017-01-01 00:00:00         NaN          NaN                    NaN  ...
# 2017-01-01 00:30:00         NaN          NaN                    NaN  ...
# 2017-01-01 01:00:00         NaN          NaN                    NaN  ...
# 2017-01-01 01:30:00         NaN          NaN                    NaN  ...
# 2017-01-01 02:00:00         NaN          NaN                    NaN  ...
# ...                         ...          ...                    ...  ...
# 2017-12-30 21:30:00   61.685000     0.075000               0.052667  ...
# 2017-12-30 22:00:00   63.106667     0.074333               0.051333  ...
# 2017-12-30 22:30:00   63.473333     0.074667               0.039333  ...
# 2017-12-30 23:00:00   64.506667     0.086000               0.066000  ...
# 2017-12-30 23:30:00   69.006667     0.081333               0.077000  ...
#
#                      WindSpeed_2  GeneralDiffuseFlows_2  DiffuseFlows_2  \
# Datetime
# 2017-01-01 00:00:00          NaN                    NaN             NaN
# 2017-01-01 00:30:00          NaN                    NaN             NaN
# 2017-01-01 01:00:00     0.082000               0.061000        0.101333
# 2017-01-01 01:30:00     0.081667               0.066000        0.096333
# 2017-01-01 02:00:00     0.082000               0.056333        0.110000
# ...                          ...                    ...             ...
# 2017-12-30 21:30:00     0.086000               0.066000        0.090000
# 2017-12-30 22:00:00     0.081333               0.077000        0.109000
# 2017-12-30 22:30:00     0.081667               0.069333        0.087667
# 2017-12-30 23:00:00     0.081000               0.062333        0.108667
# 2017-12-30 23:30:00     0.082667               0.055000        0.107667
#
#                      PowerConsumption_2  Temperature_1  Humidity_1  \
# Datetime
# 2017-01-01 00:00:00                 NaN            NaN         NaN
# 2017-01-01 00:30:00                 NaN       6.428667   74.266667
# 2017-01-01 01:00:00        30999.493670       5.941000   75.866667
# 2017-01-01 01:30:00        27396.455697       5.605000   77.900000
# 2017-01-01 02:00:00        25407.594937       5.492667   77.166667
# ...                                 ...            ...         ...
# 2017-12-30 21:30:00        36846.641317       8.110000   69.006667
# 2017-12-30 22:00:00        35930.038023       7.913333   70.343333
# 2017-12-30 22:30:00        34786.311787       7.793333   69.563333
# 2017-12-30 23:00:00        34660.583017       7.403333   71.066667
# 2017-12-30 23:30:00        33326.235743       7.009000   72.500000
#
#                      WindSpeed_1  GeneralDiffuseFlows_1  DiffuseFlows_1  \
# Datetime
# 2017-01-01 00:00:00          NaN                    NaN             NaN
# 2017-01-01 00:30:00     0.082000               0.061000        0.101333
# 2017-01-01 01:00:00     0.081667               0.066000        0.096333
# 2017-01-01 01:30:00     0.082000               0.056333        0.110000
# 2017-01-01 02:00:00     0.082000               0.057333        0.115000
# ...                          ...                    ...             ...
# 2017-12-30 21:30:00     0.081333               0.077000        0.109000
# 2017-12-30 22:00:00     0.081667               0.069333        0.087667
# 2017-12-30 22:30:00     0.081000               0.062333        0.108667
# 2017-12-30 23:00:00     0.082667               0.055000        0.107667
# 2017-12-30 23:30:00     0.080667               0.055000        0.094000
#
#                      PowerConsumption_1
# Datetime
# 2017-01-01 00:00:00                 NaN
# 2017-01-01 00:30:00        30999.493670
# 2017-01-01 01:00:00        27396.455697
# 2017-01-01 01:30:00        25407.594937
# 2017-01-01 02:00:00        23906.835443
# ...                                 ...
# 2017-12-30 21:30:00        35930.038023
# 2017-12-30 22:00:00        34786.311787
# 2017-12-30 22:30:00        34660.583017
# 2017-12-30 23:00:00        33326.235743
# 2017-12-30 23:30:00        31249.683140
#
# [17472 rows x 36 columns]

# %%
df.drop(columns=features, inplace=True)

# %%
df.dropna(axis=0, inplace=True)

# %%
df
# Out:
#                      PowerConsumption  Temperature_5  Humidity_5  WindSpeed_5  \
# Datetime
# 2017-01-01 02:30:00      21691.139240       6.428667   74.266667     0.082000
# 2017-01-01 03:00:00      20992.405063       5.941000   75.866667     0.081667
# 2017-01-01 03:30:00      20629.873417       5.605000   77.900000     0.082000
# 2017-01-01 04:00:00      20512.405063       5.492667   77.166667     0.082000
# 2017-01-01 04:30:00      20439.493670       5.000667   78.766667     0.082667
# ...                               ...            ...         ...          ...
# 2017-12-30 21:30:00      34786.311787       9.710000   61.685000     0.075000
# 2017-12-30 22:00:00      34660.583017       9.196667   63.106667     0.074333
# 2017-12-30 22:30:00      33326.235743       8.933333   63.473333     0.074667
# 2017-12-30 23:00:00      31249.683140       9.150000   64.506667     0.086000
# 2017-12-30 23:30:00      28966.286437       8.110000   69.006667     0.081333
#
#                      GeneralDiffuseFlows_5  DiffuseFlows_5  \
# Datetime
# 2017-01-01 02:30:00               0.061000        0.101333
# 2017-01-01 03:00:00               0.066000        0.096333
# 2017-01-01 03:30:00               0.056333        0.110000
# 2017-01-01 04:00:00               0.057333        0.115000
# 2017-01-01 04:30:00               0.065000        0.127333
# ...                                    ...             ...
# 2017-12-30 21:30:00               0.052667        0.108667
# 2017-12-30 22:00:00               0.051333        0.095333
# 2017-12-30 22:30:00               0.039333        0.120000
# 2017-12-30 23:00:00               0.066000        0.090000
# 2017-12-30 23:30:00               0.077000        0.109000
#
#                      PowerConsumption_5  Temperature_4  Humidity_4  \
# Datetime
# 2017-01-01 02:30:00        30999.493670       5.941000   75.866667
# 2017-01-01 03:00:00        27396.455697       5.605000   77.900000
# 2017-01-01 03:30:00        25407.594937       5.492667   77.166667
# 2017-01-01 04:00:00        23906.835443       5.000667   78.766667
# 2017-01-01 04:30:00        22474.936707       5.108000   79.100000
# ...                                 ...            ...         ...
# 2017-12-30 21:30:00        37690.240813       9.196667   63.106667
# 2017-12-30 22:00:00        37337.389100       8.933333   63.473333
# 2017-12-30 22:30:00        37171.102660       9.150000   64.506667
# 2017-12-30 23:00:00        36846.641317       8.110000   69.006667
# 2017-12-30 23:30:00        35930.038023       7.913333   70.343333
#
#                      WindSpeed_4  ...  WindSpeed_2  GeneralDiffuseFlows_2  \
# Datetime                          ...
# 2017-01-01 02:30:00     0.081667  ...     0.082000               0.057333
# 2017-01-01 03:00:00     0.082000  ...     0.082667               0.065000
# 2017-01-01 03:30:00     0.082000  ...     0.082000               0.061000
# 2017-01-01 04:00:00     0.082667  ...     0.082667               0.059667
# 2017-01-01 04:30:00     0.082000  ...     0.083000               0.060000
# ...                          ...  ...          ...                    ...
# 2017-12-30 21:30:00     0.074333  ...     0.086000               0.066000
# 2017-12-30 22:00:00     0.074667  ...     0.081333               0.077000
# 2017-12-30 22:30:00     0.086000  ...     0.081667               0.069333
# 2017-12-30 23:00:00     0.081333  ...     0.081000               0.062333
# 2017-12-30 23:30:00     0.081667  ...     0.082667               0.055000
#
#                      DiffuseFlows_2  PowerConsumption_2  Temperature_1  \
# Datetime
# 2017-01-01 02:30:00        0.115000        23906.835443       5.000667
# 2017-01-01 03:00:00        0.127333        22474.936707       5.108000
# 2017-01-01 03:30:00        0.131000        21691.139240       5.097000
# 2017-01-01 04:00:00        0.130000        20992.405063       4.911667
# 2017-01-01 04:30:00        0.152000        20629.873417       4.952333
# ...                             ...                 ...            ...
# 2017-12-30 21:30:00        0.090000        36846.641317       8.110000
# 2017-12-30 22:00:00        0.109000        35930.038023       7.913333
# 2017-12-30 22:30:00        0.087667        34786.311787       7.793333
# 2017-12-30 23:00:00        0.108667        34660.583017       7.403333
# 2017-12-30 23:30:00        0.107667        33326.235743       7.009000
#
#                      Humidity_1  WindSpeed_1  GeneralDiffuseFlows_1  \
# Datetime
# 2017-01-01 02:30:00   78.766667     0.082667               0.065000
# 2017-01-01 03:00:00   79.100000     0.082000               0.061000
# 2017-01-01 03:30:00   77.600000     0.082667               0.059667
# 2017-01-01 04:00:00   76.566667     0.083000               0.060000
# 2017-01-01 04:30:00   74.733333     0.083667               0.058667
# ...                         ...          ...                    ...
# 2017-12-30 21:30:00   69.006667     0.081333               0.077000
# 2017-12-30 22:00:00   70.343333     0.081667               0.069333
# 2017-12-30 22:30:00   69.563333     0.081000               0.062333
# 2017-12-30 23:00:00   71.066667     0.082667               0.055000
# 2017-12-30 23:30:00   72.500000     0.080667               0.055000
#
#                      DiffuseFlows_1  PowerConsumption_1
# Datetime
# 2017-01-01 02:30:00        0.127333        22474.936707
# 2017-01-01 03:00:00        0.131000        21691.139240
# 2017-01-01 03:30:00        0.130000        20992.405063
# 2017-01-01 04:00:00        0.152000        20629.873417
# 2017-01-01 04:30:00        0.117333        20512.405063
# ...                             ...                 ...
# 2017-12-30 21:30:00        0.109000        35930.038023
# 2017-12-30 22:00:00        0.087667        34786.311787
# 2017-12-30 22:30:00        0.108667        34660.583017
# 2017-12-30 23:00:00        0.107667        33326.235743
# 2017-12-30 23:30:00        0.094000        31249.683140
#
# [17467 rows x 31 columns]

# %% [markdown]
# # Split the dataset into 80% training and 20% testing datasets

# %%
from sklearn.model_selection import train_test_split

# %%
X, y = df.drop(columns=[target]), df[target]

# %%
train_X, test_X, train_y, test_y = train_test_split(X, y, test_size=0.20, shuffle=False)

# %% [markdown]
# ## Create the model, pre-process the data and make it suitable for training

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler()
train_X = scaler.fit_transform(train_X)
test_X = scaler.transform(test_X)

# %%
scaler = MinMaxScaler()
train_y = scaler.fit_transform(train_y.to_numpy().reshape(-1, 1))

# %%
# (samples, lags, features)
lag = 5
(train_X.shape[0], lag, (train_X.shape[1] // lag))
# Out:
# (13973, 5, 6)

# %%
train_X = train_X.reshape((train_X.shape[0], lag, (train_X.shape[1] // lag)))
test_X = test_X.reshape((test_X.shape[0], lag, (test_X.shape[1] // lag)))

# %%
from keras.api.models import Sequential
from keras.api.layers import Input, LSTM, Dense

# %%
train_X.shape
# Out:
# (13973, 5, 6)

# %%
model = Sequential([
    Input((train_X.shape[1], train_X.shape[2],)),
    LSTM(64, activation="relu", return_sequences=True),
    LSTM(32, activation="relu"),
    Dense(1, activation="linear")
])

# %%
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm_2 (LSTM)                   │ (None, 5, 64)          │        18,176 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_3 (LSTM)                   │ (None, 32)             │        12,416 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 1)              │            33 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30,625 (119.63 KB)
#  Trainable params: 30,625 (119.63 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    loss="mean_squared_error",
    optimizer="adam",
    metrics=["mean_squared_error"],
)

# %% [markdown]
# ## Train the model, use 20% of the training dataset for validation
# Train with 10 epochs (due to time limit)

# %%
history = model.fit(train_X, train_y, validation_split=0.20, epochs=16, batch_size=64, shuffle=False)
# Out:
# Epoch 1/16
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - loss: 0.0635 - mean_squared_error: 0.0635 - val_loss: 0.0115 - val_mean_squared_error: 0.0115
# Epoch 2/16
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0107 - mean_squared_error: 0.0107 - val_loss: 0.0101 - val_mean_squared_error: 0.0101
# Epoch 3/16
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0083 - mean_squared_error: 0.0083 - val_loss: 0.0058 - val_mean_squared_error: 0.0058
# Epoch 4/16
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0069 - mean_squared_error: 0.0069 - val_loss: 0.0048 - val_mean_squared_error: 0.0048
# Epoch 5/16
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0054 - mean_squared_error: 0.0054 - val_loss: 0.0038 - val_mean_squared_error: 0.0038
# Epoch 6/16
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0043 - mean_squared_error: 0.0043 - val_loss: 0.0029 - val_mean_squared_error: 0.0029
# Epoch 7/16
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 8ms/step - loss: 0.0034 - mean_squared_error: 0.0034 - val_loss: 0.0025 - val_mean_squared_error: 0.0025
# Epoch 8/16
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0028 - mean_squared_error: 0.0028 - val_loss: 0.0023 - val_mean_squared_error: 0.0023
# Epoch 9/16
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0024 - mean_squared_error: 0.0024 - val_loss: 0.0020 - val_mean_squared_error: 0.0020
# Epoch 10/16
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0021 - mean_squared_error: 0.0021 - val_loss: 0.0017 - val_mean_squared_error: 0.0017
# Epoch 11/16
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0018 - mean_squared_error: 0.0018 - val_loss: 0.0016 - val_mean_squared_error: 0.0016
# Epoch 12/16
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0017 - mean_squared_error: 0.0017 - val_loss: 0.0015 - val_mean_squared_error: 0.0015
# Epoch 13/16
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0015 - mean_squared_error: 0.0015 - val_loss: 0.0014 - val_mean_squared_error: 0.0014
# Epoch 14/16
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 1s 8ms/step - loss: 0.0014 - mean_squared_error: 0.0014 - val_loss: 0.0013 - val_mean_squared_error: 0.0013
# Epoch 15/16
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.0013 - mean_squared_error: 0.0013 - val_loss: 0.0011 - val_mean_squared_error: 0.0011
# Epoch 16/16
# 175/175 ━━━━━━━━━━━━━━━━━━━━ 2s 9ms/step - loss: 0.0011 - mean_squared_error: 0.0011 - val_loss: 9.5605e-04 - val_mean_squared_error: 9.5605e-04

# %% [markdown]
# ## Plot the loss function on the training and validation dataset

# %%
sns.lineplot(history.history["loss"], label="loss")
sns.lineplot(history.history["val_loss"], label="val_loss")
# Out:
# <Axes: >

# %% [markdown]
# ## Calculate the adequate metrics

# %%
pred_y = model.predict(test_X)
# Out:
# 110/110 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step

# %%
pred_y = scaler.inverse_transform(pred_y)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
(mean_absolute_error(test_y, pred_y), mean_squared_error(test_y, pred_y), r2_score(test_y, pred_y))
# Out:
# (np.float64(980.6576840267244),
#  np.float64(1572802.587137201),
#  0.9584496091517875)

# %% [markdown]
# ## Visualize the targets against the predictions

# %%
sns.lineplot(x=test_y.index, y=test_y.values)
sns.lineplot(x=test_y.index, y=pred_y.flatten())
# Out:
# <Axes: xlabel='Datetime'>
