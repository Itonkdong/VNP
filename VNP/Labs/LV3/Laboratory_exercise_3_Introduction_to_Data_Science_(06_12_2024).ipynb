# %% [markdown]
# # Requirements

# %%
import pandas as pd

# %%
# Add as many imports as you need.
# Add as many imports as you need.
# Add as many imports as you need.
# Add as many imports as you need.
import pandas as pd

from VNP.packages.data_alalysis import *
from VNP.packages.data_preperation import *
from VNP.packages.missing_values import *
from VNP.packages.visualization import *
from VNP.packages.models import *
from VNP.packages.evaluation import *
from VNP.packages.vnp_ez import *
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Laboratory Exercise - Run Mode (8 points)

# %% [markdown]
# ## Introduction
# In this laboratory assignment, the focus is on time series forecasting, specifically targeting the prediction of the current **mean temperature** in the city of Delhi. Your task involves employing bagging and boosting methods to forecast the **mean temperature**. To accomplish this use data from the preceding three days, consisting of **mean temperature**, **humidity**, **wind speed**, and **mean pressure**.
#
# **Note: You are required to perform this laboratory assignment on your local machine.**

# %% [markdown]
# ## The Climate Dataset

# %% [markdown]
# ## Downloading the Climate Dataset

# %%
# !gdown 1kczX2FpFTH1QEsDeg6dszXM3Azwyd7XC # Download the dataset.
# Out:
# 'gdown' is not recognized as an internal or external command,
# operable program or batch file.

# %% [markdown]
# ## Exploring the Climate Dataset
# This dataset consists of daily weather records for the city of Delhi spanning a period of 4 years (from 2013 to 2017). The dataset includes the following attributes:
#
# - date - date in the format YYYY-MM-DD,
# - meantemp - mean temperature averaged from multiple 3-hour intervals in a day,
# - humidity - humidity value for the day (measured in grams of water vapor per cubic meter volume of air),
# - wind_speed - wind speed measured in kilometers per hour, and
# - meanpressure - pressure reading of the weather (measured in atm).
#
# *Note: The dataset is complete, with no missing values in any of its entries.*

# %% [markdown]
# Load the dataset into a `pandas` data frame.

# %%
# Write your code here. Add as many boxes as you need.
df = pd.read_csv("./data/climate-data.csv")
df
# Out:
#             date   meantemp    humidity  wind_speed  meanpressure
# 0     2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1     2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2     2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3     2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4     2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...          ...        ...         ...         ...           ...
# 1457  2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458  2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459  2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460  2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461  2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %% [markdown]
# Explore the dataset using visualizations of your choice.

# %%
# Write your code here. Add as many boxes as you need.
df_copy = to_time_series(df, time_feature="date", auto_sort=True)
df_copy
# Out:
#              meantemp    humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...               ...         ...         ...           ...
# 2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 4 columns]

# %%
correlation_map(df_copy)

# %%
sns.pairplot(df_copy)

# %% [markdown]
# # Feauture Extraction
# Apply a lag of one, two, and three days to each feature, creating a set of features representing the meteorological conditions from the previous three days. To maintain dataset integrity, eliminate any resulting missing values at the beginning of the dataset.
#
# Hint: Use `df['column_name'].shift(period)`. Check the documentation at https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shift.html.

# %%
# Write your code here. Add as many boxes as you need.
df_copy_1, features = auto_shift(df_copy, lag=3, features_to_shift=get_numerical_features_names(df_copy),
                                 return_features=True,
                                 auto_drop_na=True)
df_copy_1
# Out:
#              meantemp    humidity  wind_speed  meanpressure  meantemp_prev_1  \
# date
# 2013-01-04   8.666667   71.333333    1.233333   1017.166667         7.166667
# 2013-01-05   6.000000   86.833333    3.700000   1016.500000         8.666667
# 2013-01-06   7.000000   82.800000    1.480000   1018.000000         6.000000
# 2013-01-07   7.000000   78.600000    6.300000   1020.000000         7.000000
# 2013-01-08   8.857143   63.714286    7.142857   1018.714286         7.000000
# ...               ...         ...         ...           ...              ...
# 2016-12-28  17.217391   68.043478    3.547826   1015.565217        16.850000
# 2016-12-29  15.238095   87.857143    6.000000   1016.904762        17.217391
# 2016-12-30  14.095238   89.666667    6.266667   1017.904762        15.238095
# 2016-12-31  15.052632   87.000000    7.325000   1016.100000        14.095238
# 2017-01-01  10.000000  100.000000    0.000000   1016.000000        15.052632
#
#             humidity_prev_1  wind_speed_prev_1  meanpressure_prev_1  \
# date
# 2013-01-04        87.000000           4.633333          1018.666667
# 2013-01-05        71.333333           1.233333          1017.166667
# 2013-01-06        86.833333           3.700000          1016.500000
# 2013-01-07        82.800000           1.480000          1018.000000
# 2013-01-08        78.600000           6.300000          1020.000000
# ...                     ...                ...                  ...
# 2016-12-28        67.550000           8.335000          1017.200000
# 2016-12-29        68.043478           3.547826          1015.565217
# 2016-12-30        87.857143           6.000000          1016.904762
# 2016-12-31        89.666667           6.266667          1017.904762
# 2017-01-01        87.000000           7.325000          1016.100000
#
#             meantemp_prev_2  humidity_prev_2  wind_speed_prev_2  \
# date
# 2013-01-04         7.400000        92.000000           2.980000
# 2013-01-05         7.166667        87.000000           4.633333
# 2013-01-06         8.666667        71.333333           1.233333
# 2013-01-07         6.000000        86.833333           3.700000
# 2013-01-08         7.000000        82.800000           1.480000
# ...                     ...              ...                ...
# 2016-12-28        17.142857        74.857143           8.784211
# 2016-12-29        16.850000        67.550000           8.335000
# 2016-12-30        17.217391        68.043478           3.547826
# 2016-12-31        15.238095        87.857143           6.000000
# 2017-01-01        14.095238        89.666667           6.266667
#
#             meanpressure_prev_2  meantemp_prev_3  humidity_prev_3  \
# date
# 2013-01-04          1017.800000        10.000000        84.500000
# 2013-01-05          1018.666667         7.400000        92.000000
# 2013-01-06          1017.166667         7.166667        87.000000
# 2013-01-07          1016.500000         8.666667        71.333333
# 2013-01-08          1018.000000         6.000000        86.833333
# ...                         ...              ...              ...
# 2016-12-28          1016.952381        14.000000        94.300000
# 2016-12-29          1017.200000        17.142857        74.857143
# 2016-12-30          1015.565217        16.850000        67.550000
# 2016-12-31          1016.904762        17.217391        68.043478
# 2017-01-01          1017.904762        15.238095        87.857143
#
#             wind_speed_prev_3  meanpressure_prev_3
# date
# 2013-01-04           0.000000          1015.666667
# 2013-01-05           2.980000          1017.800000
# 2013-01-06           4.633333          1018.666667
# 2013-01-07           1.233333          1017.166667
# 2013-01-08           3.700000          1016.500000
# ...                       ...                  ...
# 2016-12-28           9.085000          1014.350000
# 2016-12-29           8.784211          1016.952381
# 2016-12-30           8.335000          1017.200000
# 2016-12-31           3.547826          1015.565217
# 2017-01-01           6.000000          1016.904762
#
# [1459 rows x 16 columns]

# %% [markdown]
# ## Dataset Splitting
# Partition the dataset into training and testing sets with an 80:20 ratio.
#
# **WARNING: DO NOT SHUFFLE THE DATASET.**

# %%
# Write your code here. Add as many boxes as you need.
X = df_copy_1[features]
Y = df_copy_1["meantemp"]

# %%
X
# Out:
#             meantemp_prev_1  humidity_prev_1  wind_speed_prev_1  \
# date
# 2013-01-04         7.166667        87.000000           4.633333
# 2013-01-05         8.666667        71.333333           1.233333
# 2013-01-06         6.000000        86.833333           3.700000
# 2013-01-07         7.000000        82.800000           1.480000
# 2013-01-08         7.000000        78.600000           6.300000
# ...                     ...              ...                ...
# 2016-12-28        16.850000        67.550000           8.335000
# 2016-12-29        17.217391        68.043478           3.547826
# 2016-12-30        15.238095        87.857143           6.000000
# 2016-12-31        14.095238        89.666667           6.266667
# 2017-01-01        15.052632        87.000000           7.325000
#
#             meanpressure_prev_1  meantemp_prev_2  humidity_prev_2  \
# date
# 2013-01-04          1018.666667         7.400000        92.000000
# 2013-01-05          1017.166667         7.166667        87.000000
# 2013-01-06          1016.500000         8.666667        71.333333
# 2013-01-07          1018.000000         6.000000        86.833333
# 2013-01-08          1020.000000         7.000000        82.800000
# ...                         ...              ...              ...
# 2016-12-28          1017.200000        17.142857        74.857143
# 2016-12-29          1015.565217        16.850000        67.550000
# 2016-12-30          1016.904762        17.217391        68.043478
# 2016-12-31          1017.904762        15.238095        87.857143
# 2017-01-01          1016.100000        14.095238        89.666667
#
#             wind_speed_prev_2  meanpressure_prev_2  meantemp_prev_3  \
# date
# 2013-01-04           2.980000          1017.800000        10.000000
# 2013-01-05           4.633333          1018.666667         7.400000
# 2013-01-06           1.233333          1017.166667         7.166667
# 2013-01-07           3.700000          1016.500000         8.666667
# 2013-01-08           1.480000          1018.000000         6.000000
# ...                       ...                  ...              ...
# 2016-12-28           8.784211          1016.952381        14.000000
# 2016-12-29           8.335000          1017.200000        17.142857
# 2016-12-30           3.547826          1015.565217        16.850000
# 2016-12-31           6.000000          1016.904762        17.217391
# 2017-01-01           6.266667          1017.904762        15.238095
#
#             humidity_prev_3  wind_speed_prev_3  meanpressure_prev_3
# date
# 2013-01-04        84.500000           0.000000          1015.666667
# 2013-01-05        92.000000           2.980000          1017.800000
# 2013-01-06        87.000000           4.633333          1018.666667
# 2013-01-07        71.333333           1.233333          1017.166667
# 2013-01-08        86.833333           3.700000          1016.500000
# ...                     ...                ...                  ...
# 2016-12-28        94.300000           9.085000          1014.350000
# 2016-12-29        74.857143           8.784211          1016.952381
# 2016-12-30        67.550000           8.335000          1017.200000
# 2016-12-31        68.043478           3.547826          1015.565217
# 2017-01-01        87.857143           6.000000          1016.904762
#
# [1459 rows x 12 columns]

# %%
Y
# Out:
# date
# 2013-01-04     8.666667
# 2013-01-05     6.000000
# 2013-01-06     7.000000
# 2013-01-07     7.000000
# 2013-01-08     8.857143
#                 ...
# 2016-12-28    17.217391
# 2016-12-29    15.238095
# 2016-12-30    14.095238
# 2016-12-31    15.052632
# 2017-01-01    10.000000
# Name: meantemp, Length: 1459, dtype: float64

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.2, shuffle=False)

# %% [markdown]
# ## Ensemble Learning Methods

# %% [markdown]
# ### Bagging

# %% [markdown]
# Create an instance of a Random Forest model and train it using the `fit` function.

# %%
# Write your code here. Add as many boxes as you need.
# random_forest_regressor = RandomForestRegressor(max_depth=8, random_state=0, n_estimators=200)
random_forest_regressor = RandomForestRegressor()
random_forest_regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor()

# %% [markdown]
# Use the trained model to make predictions for the test set.

# %%
# Write your code here. Add as many boxes as you need.
forest_regressor_predict = random_forest_regressor.predict(x_test)

# %% [markdown]
# Assess the performance of the model by using different metrics provided by the `scikit-learn` library.

# %%
# Write your code here. Add as many boxes as you need.
regression_report(y_test, forest_regressor_predict)
# Out:
# Regression Report:
# Mean Square Error: 3.0933584979383952
# R2 Score: 0.9034276883234559

# %%
show_time_series_predicts(y_test, forest_regressor_predict)

# %% [markdown]
# ### Boosting

# %% [markdown]
# Create an instance of an XGBoost model and train it using the `fit` function.

# %%
# Write your code here. Add as many boxes as you need.
xgb_regressor = XGBRegressor(max_depth=4, random_state=0, n_estimators=200)
xgb_regressor.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=4, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=200, n_jobs=None,
#              num_parallel_tree=None, random_state=0, ...)

# %% [markdown]
# Use the trained model to make predictions for the test set.

# %%
# Write your code here. Add as many boxes as you need.
xgb_regressor_predict = xgb_regressor.predict(x_test)

# %% [markdown]
# Assess the performance of the model by using different metrics provided by the `scikit-learn` library.

# %%
# Write your code here. Add as many boxes as you need.
regression_report(y_test, xgb_regressor_predict)
# Out:
# Regression Report:
# Mean Square Error: 3.81740806131426
# R2 Score: 0.8808234088161823

# %%
show_time_series_predicts(y_test, xgb_regressor_predict)

# %% [markdown]
# # Laboratory Exercise - Bonus Task (+ 2 points)

# %% [markdown]
# As part of the bonus task in this laboratory assignment, your objective is to fine-tune the number of estimators (`n_estimators`) for the XGBoost model using a cross-validation with grid search and time series split. This involves systematically experimenting with various values for `n_estimators` and evaluating the model's performance using cross-validation. Upon determining the most suitable `n_estimators` value, evaluate the model's performance on a test set for final assessment.
#
# Hints:
# - For grid search use the `GridCVSearch` from the `scikit-learn` library. Check the documentation at https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html.
# - For cross-validation use the `TimeSeriesSplit` from the `scikit-learn` library. Check the documentation at https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html.

# %% [markdown]
# ## Dataset Splitting
# Partition the dataset into training and testing sets with an 90:10 ratio.
#
# **WARNING: DO NOT SHUFFLE THE DATASET.**

# %%
df_copy
# Out:
#              meantemp    humidity  wind_speed  meanpressure
# date
# 2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...               ...         ...         ...           ...
# 2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 4 columns]

# %%
# X = df_copy.drop(columns="meantemp")
# Y = df_copy["meantemp"]

# %%
# Write your code here. Add as many boxes as you need.
# x_train_scaled,x_test_scaled,scaler = scale_data(x_train, x_test, strategy="minmax")

# %%
scaler = MinMaxScaler()
scaler.fit(x_train)
x_train_scaled = scaler.transform(x_train)
x_test_scaled = scaler.transform(x_test)
y_train_scaled = scaler.fit_transform(y_train.values.reshape(-1, 1))

# %%
x_train_scaled
# Out:
# array([[0.0356623 , 0.86993243, 0.10974262, ..., 0.84037162, 0.        ,
#         0.76811594],
#        [0.08151383, 0.68468468, 0.02921206, ..., 0.92905405, 0.07058266,
#         0.83557312],
#        [0.        , 0.86796171, 0.08763619, ..., 0.86993243, 0.10974262,
#         0.8629776 ],
#        ...,
#        [0.56741266, 0.63270693, 0.22471577, ..., 0.52037584, 0.18903955,
#         0.68972332],
#        [0.55786026, 0.61201436, 0.16209735, ..., 0.64290541, 0.15506079,
#         0.66903821],
#        [0.50054585, 0.62162162, 0.14862624, ..., 0.63270693, 0.22471577,
#         0.57509881]])

# %%
df
# Out:
#             date   meantemp    humidity  wind_speed  meanpressure
# 0     2013-01-01  10.000000   84.500000    0.000000   1015.666667
# 1     2013-01-02   7.400000   92.000000    2.980000   1017.800000
# 2     2013-01-03   7.166667   87.000000    4.633333   1018.666667
# 3     2013-01-04   8.666667   71.333333    1.233333   1017.166667
# 4     2013-01-05   6.000000   86.833333    3.700000   1016.500000
# ...          ...        ...         ...         ...           ...
# 1457  2016-12-28  17.217391   68.043478    3.547826   1015.565217
# 1458  2016-12-29  15.238095   87.857143    6.000000   1016.904762
# 1459  2016-12-30  14.095238   89.666667    6.266667   1017.904762
# 1460  2016-12-31  15.052632   87.000000    7.325000   1016.100000
# 1461  2017-01-01  10.000000  100.000000    0.000000   1016.000000
#
# [1462 rows x 5 columns]

# %%
x_train_scaled_shaped = x_train_scaled.reshape(x_train_scaled.shape[0], x_train_scaled.shape[1], 1)

# %%
x_test_scaled_shaped = x_test_scaled.reshape(x_test_scaled.shape[0], x_test_scaled.shape[1], 1)

# %%
x_train_scaled_shaped
# Out:
# array([[[0.0356623 ],
#         [0.86993243],
#         [0.10974262],
#         ...,
#         [0.84037162],
#         [0.        ],
#         [0.76811594]],
#
#        [[0.08151383],
#         [0.68468468],
#         [0.02921206],
#         ...,
#         [0.92905405],
#         [0.07058266],
#         [0.83557312]],
#
#        [[0.        ],
#         [0.86796171],
#         [0.08763619],
#         ...,
#         [0.86993243],
#         [0.10974262],
#         [0.8629776 ]],
#
#        ...,
#
#        [[0.56741266],
#         [0.63270693],
#         [0.22471577],
#         ...,
#         [0.52037584],
#         [0.18903955],
#         [0.68972332]],
#
#        [[0.55786026],
#         [0.61201436],
#         [0.16209735],
#         ...,
#         [0.64290541],
#         [0.15506079],
#         [0.66903821]],
#
#        [[0.50054585],
#         [0.62162162],
#         [0.14862624],
#         ...,
#         [0.63270693],
#         [0.22471577],
#         [0.57509881]]])

# %% [markdown]
# ## Fine-tuning the XGBoost Hyperparameter
# Experiment with various values for `n_estimators` and evaluate the model's performance using cross-validation.

# %%
import keras
import tensorflow as tf

# %%
from keras.api.models import Sequential
from keras.api.layers import LSTM, Dense, Dropout
import keras

# %%
# Write your code here. Add as many boxes as you need.
model = Sequential()
model.add(LSTM(100, activation='relu', input_shape=(x_train_scaled_shaped.shape[1], x_train_scaled_shaped.shape[2]),
               return_sequences=True))
model.add(LSTM(50, activation='relu'))
model.add(Dense(1, activation='linear'))
# Out:
# D:\Fax\LAIP\.venv\Lib\site-packages\keras\src\layers\rnn\rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
model.compile(loss=keras.losses.MeanSquaredError(), optimizer=keras.optimizers.Adam(),
              metrics=[keras.metrics.MeanSquaredError(), keras.metrics.MeanAbsoluteError()])

# %%
history = model.fit(x_train_scaled_shaped, y_train_scaled, batch_size=16, validation_split=0.2, epochs=40,
                    shuffle=False)
# Out:
# Epoch 1/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0044 - mean_absolute_error: 0.0518 - mean_squared_error: 0.0044 - val_loss: 0.0023 - val_mean_absolute_error: 0.0377 - val_mean_squared_error: 0.0023
# Epoch 2/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0044 - mean_absolute_error: 0.0516 - mean_squared_error: 0.0044 - val_loss: 0.0023 - val_mean_absolute_error: 0.0378 - val_mean_squared_error: 0.0023
# Epoch 3/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0043 - mean_absolute_error: 0.0516 - mean_squared_error: 0.0043 - val_loss: 0.0023 - val_mean_absolute_error: 0.0380 - val_mean_squared_error: 0.0023
# Epoch 4/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0043 - mean_absolute_error: 0.0515 - mean_squared_error: 0.0043 - val_loss: 0.0023 - val_mean_absolute_error: 0.0384 - val_mean_squared_error: 0.0023
# Epoch 5/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0043 - mean_absolute_error: 0.0514 - mean_squared_error: 0.0043 - val_loss: 0.0023 - val_mean_absolute_error: 0.0386 - val_mean_squared_error: 0.0023
# Epoch 6/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0043 - mean_absolute_error: 0.0514 - mean_squared_error: 0.0043 - val_loss: 0.0024 - val_mean_absolute_error: 0.0389 - val_mean_squared_error: 0.0024
# Epoch 7/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0043 - mean_absolute_error: 0.0513 - mean_squared_error: 0.0043 - val_loss: 0.0024 - val_mean_absolute_error: 0.0392 - val_mean_squared_error: 0.0024
# Epoch 8/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0043 - mean_absolute_error: 0.0513 - mean_squared_error: 0.0043 - val_loss: 0.0024 - val_mean_absolute_error: 0.0396 - val_mean_squared_error: 0.0024
# Epoch 9/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0043 - mean_absolute_error: 0.0512 - mean_squared_error: 0.0043 - val_loss: 0.0025 - val_mean_absolute_error: 0.0399 - val_mean_squared_error: 0.0025
# Epoch 10/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0043 - mean_absolute_error: 0.0512 - mean_squared_error: 0.0043 - val_loss: 0.0025 - val_mean_absolute_error: 0.0402 - val_mean_squared_error: 0.0025
# Epoch 11/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0043 - mean_absolute_error: 0.0512 - mean_squared_error: 0.0043 - val_loss: 0.0025 - val_mean_absolute_error: 0.0406 - val_mean_squared_error: 0.0025
# Epoch 12/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0043 - mean_absolute_error: 0.0511 - mean_squared_error: 0.0043 - val_loss: 0.0026 - val_mean_absolute_error: 0.0409 - val_mean_squared_error: 0.0026
# Epoch 13/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0042 - mean_absolute_error: 0.0510 - mean_squared_error: 0.0042 - val_loss: 0.0026 - val_mean_absolute_error: 0.0412 - val_mean_squared_error: 0.0026
# Epoch 14/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0042 - mean_absolute_error: 0.0510 - mean_squared_error: 0.0042 - val_loss: 0.0026 - val_mean_absolute_error: 0.0416 - val_mean_squared_error: 0.0026
# Epoch 15/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0042 - mean_absolute_error: 0.0510 - mean_squared_error: 0.0042 - val_loss: 0.0027 - val_mean_absolute_error: 0.0420 - val_mean_squared_error: 0.0027
# Epoch 16/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - loss: 0.0042 - mean_absolute_error: 0.0509 - mean_squared_error: 0.0042 - val_loss: 0.0027 - val_mean_absolute_error: 0.0423 - val_mean_squared_error: 0.0027
# Epoch 17/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0042 - mean_absolute_error: 0.0509 - mean_squared_error: 0.0042 - val_loss: 0.0027 - val_mean_absolute_error: 0.0427 - val_mean_squared_error: 0.0027
# Epoch 18/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0042 - mean_absolute_error: 0.0508 - mean_squared_error: 0.0042 - val_loss: 0.0028 - val_mean_absolute_error: 0.0431 - val_mean_squared_error: 0.0028
# Epoch 19/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0042 - mean_absolute_error: 0.0508 - mean_squared_error: 0.0042 - val_loss: 0.0028 - val_mean_absolute_error: 0.0437 - val_mean_squared_error: 0.0028
# Epoch 20/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0042 - mean_absolute_error: 0.0507 - mean_squared_error: 0.0042 - val_loss: 0.0028 - val_mean_absolute_error: 0.0440 - val_mean_squared_error: 0.0028
# Epoch 21/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0042 - mean_absolute_error: 0.0506 - mean_squared_error: 0.0042 - val_loss: 0.0029 - val_mean_absolute_error: 0.0443 - val_mean_squared_error: 0.0029
# Epoch 22/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0042 - mean_absolute_error: 0.0505 - mean_squared_error: 0.0042 - val_loss: 0.0029 - val_mean_absolute_error: 0.0447 - val_mean_squared_error: 0.0029
# Epoch 23/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0042 - mean_absolute_error: 0.0505 - mean_squared_error: 0.0042 - val_loss: 0.0030 - val_mean_absolute_error: 0.0451 - val_mean_squared_error: 0.0030
# Epoch 24/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0042 - mean_absolute_error: 0.0504 - mean_squared_error: 0.0042 - val_loss: 0.0030 - val_mean_absolute_error: 0.0455 - val_mean_squared_error: 0.0030
# Epoch 25/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0042 - mean_absolute_error: 0.0503 - mean_squared_error: 0.0042 - val_loss: 0.0030 - val_mean_absolute_error: 0.0458 - val_mean_squared_error: 0.0030
# Epoch 26/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0041 - mean_absolute_error: 0.0502 - mean_squared_error: 0.0041 - val_loss: 0.0031 - val_mean_absolute_error: 0.0462 - val_mean_squared_error: 0.0031
# Epoch 27/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0041 - mean_absolute_error: 0.0502 - mean_squared_error: 0.0041 - val_loss: 0.0031 - val_mean_absolute_error: 0.0466 - val_mean_squared_error: 0.0031
# Epoch 28/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0041 - mean_absolute_error: 0.0500 - mean_squared_error: 0.0041 - val_loss: 0.0031 - val_mean_absolute_error: 0.0469 - val_mean_squared_error: 0.0031
# Epoch 29/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0041 - mean_absolute_error: 0.0500 - mean_squared_error: 0.0041 - val_loss: 0.0032 - val_mean_absolute_error: 0.0473 - val_mean_squared_error: 0.0032
# Epoch 30/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0041 - mean_absolute_error: 0.0499 - mean_squared_error: 0.0041 - val_loss: 0.0032 - val_mean_absolute_error: 0.0477 - val_mean_squared_error: 0.0032
# Epoch 31/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0041 - mean_absolute_error: 0.0497 - mean_squared_error: 0.0041 - val_loss: 0.0033 - val_mean_absolute_error: 0.0480 - val_mean_squared_error: 0.0033
# Epoch 32/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0041 - mean_absolute_error: 0.0496 - mean_squared_error: 0.0041 - val_loss: 0.0033 - val_mean_absolute_error: 0.0484 - val_mean_squared_error: 0.0033
# Epoch 33/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0041 - mean_absolute_error: 0.0495 - mean_squared_error: 0.0041 - val_loss: 0.0033 - val_mean_absolute_error: 0.0487 - val_mean_squared_error: 0.0033
# Epoch 34/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0040 - mean_absolute_error: 0.0494 - mean_squared_error: 0.0040 - val_loss: 0.0034 - val_mean_absolute_error: 0.0491 - val_mean_squared_error: 0.0034
# Epoch 35/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0040 - mean_absolute_error: 0.0493 - mean_squared_error: 0.0040 - val_loss: 0.0034 - val_mean_absolute_error: 0.0494 - val_mean_squared_error: 0.0034
# Epoch 36/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0040 - mean_absolute_error: 0.0492 - mean_squared_error: 0.0040 - val_loss: 0.0035 - val_mean_absolute_error: 0.0498 - val_mean_squared_error: 0.0035
# Epoch 37/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - loss: 0.0040 - mean_absolute_error: 0.0490 - mean_squared_error: 0.0040 - val_loss: 0.0035 - val_mean_absolute_error: 0.0501 - val_mean_squared_error: 0.0035
# Epoch 38/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0040 - mean_absolute_error: 0.0489 - mean_squared_error: 0.0040 - val_loss: 0.0035 - val_mean_absolute_error: 0.0504 - val_mean_squared_error: 0.0035
# Epoch 39/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 13ms/step - loss: 0.0040 - mean_absolute_error: 0.0487 - mean_squared_error: 0.0040 - val_loss: 0.0036 - val_mean_absolute_error: 0.0508 - val_mean_squared_error: 0.0036
# Epoch 40/40
# 59/59 ━━━━━━━━━━━━━━━━━━━━ 1s 12ms/step - loss: 0.0039 - mean_absolute_error: 0.0486 - mean_squared_error: 0.0039 - val_loss: 0.0036 - val_mean_absolute_error: 0.0510 - val_mean_squared_error: 0.0036

# %%
lstm_predicts = model.predict(x_test_scaled_shaped)
# Out:
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step

# %%
lstm_predicts = scaler.inverse_transform(lstm_predicts)

# %%
regression_report(y_test, lstm_predicts)
# Out:
# Regression Report:
# Mean Square Error: 932.0848523861011
# R2 Score: -28.09898381762306

# %%
show_time_series_predicts(y_test, lstm_predicts)

# %% [markdown]
# ## Final Assessment of the Model Performance
# Upon determining the most suitable `n_estimators` value, evaluate the model's performance on a test set for final assessment.

# %%
# Write your code here. Add as many boxes as you need.
