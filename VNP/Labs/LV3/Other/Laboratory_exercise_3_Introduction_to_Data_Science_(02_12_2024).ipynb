# %% [markdown]
# # Requirements

# %%
import pandas as pd

# %%
# Add as many imports as you need.
import pandas as pd

from VNP.packages.data_alalysis import *
from VNP.packages.data_preperation import *
from VNP.packages.missing_values import *
from VNP.packages.visualization import *
from VNP.packages.models import *
from VNP.packages.evaluation import *
from VNP.packages.vnp_ez import *
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# # Laboratory Exercise - Run Mode (8 points)

# %% [markdown]
# ## Introduction
# In this laboratory assignment, the focus is on time series forecasting, specifically targeting the prediction of the current **average sea-level pressure** in the city of Skopje. Your task involves employing bagging and boosting methods to forecast the average sea-level pressure. To accomplish this, you will use data from the preceding three days, consisting of average, minimal, and maximal temperatures, precipitation, as well as wind direction and speed, and the current season. By applying these ensemble learning techniques, you aim to enhance the accuracy and reliability of your predictions, gaining valuable insights into the temporal dynamics of sea-level pressure based on the given meteorological variables.
#
# **Note: You are required to perform this laboratory assignment on your local machine.**

# %% [markdown]
# ## The Weather Dataset

# %% [markdown]
# ## Exploring the Weather Dataset
# This dataset consists of daily weather records for the city of Skopje from January 1, 2021, to August 1, 2023. Each entry includes a unique station ID, city name, date, corresponding season (e.g., summer, winter), and various meteorological parameters such as average, minimum, and maximum temperatures in Celsius, precipitation in millimeters, average wind direction in degrees, average wind speed in kilometers per hour, and average sea-level pressure in hectopascals. The dataset offers comprehensive insights into the climatic conditions, allowing for analysis and exploration of weather patterns in Skopje over the specified time period.
#
# The dataset comprises the following columns:
# - station_id - unique ID for the weather station,
# - city_name - name of the city where the station is located,
# - date - date of the weather record,
# - season - season corresponding to the date (e.g., summer, winter),
# - avg_temp_c - average temperature in Celsius,
# - min_temp_c - minimum temperature in Celsius,
# - max_temp_c - maximum temperature in Celsius,
# - precipitation_mm - precipitation in millimeters,
# - avg_wind_dir_deg - average wind direction in degrees,
# - avg_wind_speed_kmh - average wind speed in kilometers per hour, and
# - avg_sea_level_pres_hpa - average sea-level pressure in hectopascals.
#
# *Note: The dataset is complete, with no missing values in any of its entries.*

# %% [markdown]
# Load the dataset into a `pandas` data frame.

# %%
# Write your code here. Add as many boxes as you need.
df = pd.read_csv("./data/weather.csv")
df
# Out:
#      station_id city_name        date  season  avg_temp_c  min_temp_c  \
# 0         13588    Skopje  2021-01-01  Winter         5.1         0.5
# 1         13588    Skopje  2021-01-02  Winter         3.0        -2.6
# 2         13588    Skopje  2021-01-03  Winter         6.8         3.5
# 3         13588    Skopje  2021-01-04  Winter         6.6         6.1
# 4         13588    Skopje  2021-01-05  Winter         4.3         2.3
# ..          ...       ...         ...     ...         ...         ...
# 938       13588    Skopje  2023-07-28  Summer        22.8        12.3
# 939       13588    Skopje  2023-07-29  Summer        26.3        16.3
# 940       13588    Skopje  2023-07-30  Summer        28.2        19.5
# 941       13588    Skopje  2023-07-31  Summer        25.8        20.9
# 942       13588    Skopje  2023-08-01  Summer        25.8        17.3
#
#      max_temp_c  precipitation_mm  avg_wind_dir_deg  avg_wind_speed_kmh  \
# 0          13.2               0.0             330.0                 5.9
# 1          11.2               0.0             330.0                 5.9
# 2          12.5               1.3             339.0                 8.0
# 3           7.2               3.6             298.0                 5.3
# 4           6.7               4.6              11.0                 5.1
# ..          ...               ...               ...                 ...
# 938        32.7               0.0               2.0                 6.8
# 939        35.4               0.0             261.0                 6.2
# 940        36.4               0.0             317.0                 8.0
# 941        32.1               0.0             307.0                12.3
# 942        33.9               0.0             309.0                 8.0
#
#      avg_sea_level_pres_hpa
# 0                    1021.2
# 1                    1021.2
# 2                    1017.8
# 3                    1011.3
# 4                    1014.5
# ..                      ...
# 938                  1014.6
# 939                  1011.7
# 940                  1009.8
# 941                  1010.9
# 942                  1008.7
#
# [943 rows x 11 columns]

# %% [markdown]
# Explore the dataset using visualizations of your choice.

# %%
# Write your code here. Add as many boxes as you need.
df["city_name"].unique()
# Out:
# array(['Skopje'], dtype=object)

# %%
df_copy = df.drop(columns="city_name", axis=1)
df_copy = df_copy.drop(columns="station_id", axis=1)
df_copy
# Out:
#            date  season  avg_temp_c  min_temp_c  max_temp_c  precipitation_mm  \
# 0    2021-01-01  Winter         5.1         0.5        13.2               0.0
# 1    2021-01-02  Winter         3.0        -2.6        11.2               0.0
# 2    2021-01-03  Winter         6.8         3.5        12.5               1.3
# 3    2021-01-04  Winter         6.6         6.1         7.2               3.6
# 4    2021-01-05  Winter         4.3         2.3         6.7               4.6
# ..          ...     ...         ...         ...         ...               ...
# 938  2023-07-28  Summer        22.8        12.3        32.7               0.0
# 939  2023-07-29  Summer        26.3        16.3        35.4               0.0
# 940  2023-07-30  Summer        28.2        19.5        36.4               0.0
# 941  2023-07-31  Summer        25.8        20.9        32.1               0.0
# 942  2023-08-01  Summer        25.8        17.3        33.9               0.0
#
#      avg_wind_dir_deg  avg_wind_speed_kmh  avg_sea_level_pres_hpa
# 0               330.0                 5.9                  1021.2
# 1               330.0                 5.9                  1021.2
# 2               339.0                 8.0                  1017.8
# 3               298.0                 5.3                  1011.3
# 4                11.0                 5.1                  1014.5
# ..                ...                 ...                     ...
# 938               2.0                 6.8                  1014.6
# 939             261.0                 6.2                  1011.7
# 940             317.0                 8.0                  1009.8
# 941             307.0                12.3                  1010.9
# 942             309.0                 8.0                  1008.7
#
# [943 rows x 9 columns]

# %%
df_copy_1 = to_time_series(df_copy, time_feature="date")
df_copy_1
# Out:
#             season  avg_temp_c  min_temp_c  max_temp_c  precipitation_mm  \
# date
# 2021-01-01  Winter         5.1         0.5        13.2               0.0
# 2021-01-02  Winter         3.0        -2.6        11.2               0.0
# 2021-01-03  Winter         6.8         3.5        12.5               1.3
# 2021-01-04  Winter         6.6         6.1         7.2               3.6
# 2021-01-05  Winter         4.3         2.3         6.7               4.6
# ...            ...         ...         ...         ...               ...
# 2023-07-28  Summer        22.8        12.3        32.7               0.0
# 2023-07-29  Summer        26.3        16.3        35.4               0.0
# 2023-07-30  Summer        28.2        19.5        36.4               0.0
# 2023-07-31  Summer        25.8        20.9        32.1               0.0
# 2023-08-01  Summer        25.8        17.3        33.9               0.0
#
#             avg_wind_dir_deg  avg_wind_speed_kmh  avg_sea_level_pres_hpa
# date
# 2021-01-01             330.0                 5.9                  1021.2
# 2021-01-02             330.0                 5.9                  1021.2
# 2021-01-03             339.0                 8.0                  1017.8
# 2021-01-04             298.0                 5.3                  1011.3
# 2021-01-05              11.0                 5.1                  1014.5
# ...                      ...                 ...                     ...
# 2023-07-28               2.0                 6.8                  1014.6
# 2023-07-29             261.0                 6.2                  1011.7
# 2023-07-30             317.0                 8.0                  1009.8
# 2023-07-31             307.0                12.3                  1010.9
# 2023-08-01             309.0                 8.0                  1008.7
#
# [943 rows x 8 columns]

# %%
sns.pairplot(df_copy_1)

# %%
# df_copy_1, encoders =encode_data(df_copy_1, get_categorical_features_names(df_copy_1))

# %%
df_copy_1
# Out:
#             season  avg_temp_c  min_temp_c  max_temp_c  precipitation_mm  \
# date
# 2021-01-01  Winter         5.1         0.5        13.2               0.0
# 2021-01-02  Winter         3.0        -2.6        11.2               0.0
# 2021-01-03  Winter         6.8         3.5        12.5               1.3
# 2021-01-04  Winter         6.6         6.1         7.2               3.6
# 2021-01-05  Winter         4.3         2.3         6.7               4.6
# ...            ...         ...         ...         ...               ...
# 2023-07-28  Summer        22.8        12.3        32.7               0.0
# 2023-07-29  Summer        26.3        16.3        35.4               0.0
# 2023-07-30  Summer        28.2        19.5        36.4               0.0
# 2023-07-31  Summer        25.8        20.9        32.1               0.0
# 2023-08-01  Summer        25.8        17.3        33.9               0.0
#
#             avg_wind_dir_deg  avg_wind_speed_kmh  avg_sea_level_pres_hpa
# date
# 2021-01-01             330.0                 5.9                  1021.2
# 2021-01-02             330.0                 5.9                  1021.2
# 2021-01-03             339.0                 8.0                  1017.8
# 2021-01-04             298.0                 5.3                  1011.3
# 2021-01-05              11.0                 5.1                  1014.5
# ...                      ...                 ...                     ...
# 2023-07-28               2.0                 6.8                  1014.6
# 2023-07-29             261.0                 6.2                  1011.7
# 2023-07-30             317.0                 8.0                  1009.8
# 2023-07-31             307.0                12.3                  1010.9
# 2023-08-01             309.0                 8.0                  1008.7
#
# [943 rows x 8 columns]

# %%
correlation_map(df_copy_1)

# %% [markdown]
# Remove the highly correlated features.

# %%
# Write your code here. Add as many boxes as you need.
df_copy_2 = df_copy_1.drop(columns=["min_temp_c", "max_temp_c"], axis=1)
correlation_map(df_copy_2)

# %% [markdown]
# Encode the categorical features.

# %%
# Write your code here. Add as many boxes as you need.
missing_table(df_copy_2)
# Out:
#                   Feature  CountMissing  PercentageMissing  Total
# 0                  season             0                0.0    943
# 1              avg_temp_c             0                0.0    943
# 2        precipitation_mm             0                0.0    943
# 3        avg_wind_dir_deg             0                0.0    943
# 4      avg_wind_speed_kmh             0                0.0    943
# 5  avg_sea_level_pres_hpa             0                0.0    943

# %% [markdown]
# # Feauture Extraction
# Select the relevant features for prediction and apply a lag of one, two, and three days to each chosen feature (except `season`), creating a set of features representing the meteorological conditions from the previous three days. To maintain dataset integrity, eliminate any resulting missing values at the beginning of the dataset.
#
# Hint: Use `df['column_name'].shift(period)`. Check the documentation at https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shift.html.

# %%
df_copy_2.columns
# Out:
# Index(['season', 'avg_temp_c', 'precipitation_mm', 'avg_wind_dir_deg',
#        'avg_wind_speed_kmh', 'avg_sea_level_pres_hpa'],
#       dtype='object')

# %%
# Write your code here. Add as many boxes as you need.
df_copy_3, features = auto_shift(df_copy_2, lag=3, features_to_shift=get_numerical_features_names(df_copy_2),
                                 auto_drop_na=True, return_features=True)
df_copy_3
# Out:
#             season  avg_temp_c  precipitation_mm  avg_wind_dir_deg  \
# date
# 2021-01-04  Winter         6.6               3.6             298.0
# 2021-01-05  Winter         4.3               4.6              11.0
# 2021-01-06  Winter         6.2               0.0              18.0
# 2021-01-07  Winter         7.3               0.5               0.0
# 2021-01-08  Winter         5.7               7.9             346.0
# ...            ...         ...               ...               ...
# 2023-07-28  Summer        22.8               0.0               2.0
# 2023-07-29  Summer        26.3               0.0             261.0
# 2023-07-30  Summer        28.2               0.0             317.0
# 2023-07-31  Summer        25.8               0.0             307.0
# 2023-08-01  Summer        25.8               0.0             309.0
#
#             avg_wind_speed_kmh  avg_sea_level_pres_hpa  avg_temp_c_prev_1  \
# date
# 2021-01-04                 5.3                  1011.3                6.8
# 2021-01-05                 5.1                  1014.5                6.6
# 2021-01-06                 6.7                  1017.2                4.3
# 2021-01-07                 4.5                  1015.2                6.2
# 2021-01-08                 6.5                  1009.7                7.3
# ...                        ...                     ...                ...
# 2023-07-28                 6.8                  1014.6               20.7
# 2023-07-29                 6.2                  1011.7               22.8
# 2023-07-30                 8.0                  1009.8               26.3
# 2023-07-31                12.3                  1010.9               28.2
# 2023-08-01                 8.0                  1008.7               25.8
#
#             precipitation_mm_prev_1  avg_wind_dir_deg_prev_1  \
# date
# 2021-01-04                      1.3                    339.0
# 2021-01-05                      3.6                    298.0
# 2021-01-06                      4.6                     11.0
# 2021-01-07                      0.0                     18.0
# 2021-01-08                      0.5                      0.0
# ...                             ...                      ...
# 2023-07-28                      0.0                    316.0
# 2023-07-29                      0.0                      2.0
# 2023-07-30                      0.0                    261.0
# 2023-07-31                      0.0                    317.0
# 2023-08-01                      0.0                    307.0
#
#             avg_wind_speed_kmh_prev_1  ...  avg_temp_c_prev_2  \
# date                                   ...
# 2021-01-04                        8.0  ...                3.0
# 2021-01-05                        5.3  ...                6.8
# 2021-01-06                        5.1  ...                6.6
# 2021-01-07                        6.7  ...                4.3
# 2021-01-08                        4.5  ...                6.2
# ...                               ...  ...                ...
# 2023-07-28                       16.0  ...               28.2
# 2023-07-29                        6.8  ...               20.7
# 2023-07-30                        6.2  ...               22.8
# 2023-07-31                        8.0  ...               26.3
# 2023-08-01                       12.3  ...               28.2
#
#             precipitation_mm_prev_2  avg_wind_dir_deg_prev_2  \
# date
# 2021-01-04                      0.0                    330.0
# 2021-01-05                      1.3                    339.0
# 2021-01-06                      3.6                    298.0
# 2021-01-07                      4.6                     11.0
# 2021-01-08                      0.0                     18.0
# ...                             ...                      ...
# 2023-07-28                      0.0                    242.0
# 2023-07-29                      0.0                    316.0
# 2023-07-30                      0.0                      2.0
# 2023-07-31                      0.0                    261.0
# 2023-08-01                      0.0                    317.0
#
#             avg_wind_speed_kmh_prev_2  avg_sea_level_pres_hpa_prev_2  \
# date
# 2021-01-04                        5.9                         1021.2
# 2021-01-05                        8.0                         1017.8
# 2021-01-06                        5.3                         1011.3
# 2021-01-07                        5.1                         1014.5
# 2021-01-08                        6.7                         1017.2
# ...                               ...                            ...
# 2023-07-28                       13.4                         1002.9
# 2023-07-29                       16.0                         1012.6
# 2023-07-30                        6.8                         1014.6
# 2023-07-31                        6.2                         1011.7
# 2023-08-01                        8.0                         1009.8
#
#             avg_temp_c_prev_3  precipitation_mm_prev_3  \
# date
# 2021-01-04                5.1                      0.0
# 2021-01-05                3.0                      0.0
# 2021-01-06                6.8                      1.3
# 2021-01-07                6.6                      3.6
# 2021-01-08                4.3                      4.6
# ...                       ...                      ...
# 2023-07-28               29.2                      0.0
# 2023-07-29               28.2                      0.0
# 2023-07-30               20.7                      0.0
# 2023-07-31               22.8                      0.0
# 2023-08-01               26.3                      0.0
#
#             avg_wind_dir_deg_prev_3  avg_wind_speed_kmh_prev_3  \
# date
# 2021-01-04                    330.0                        5.9
# 2021-01-05                    330.0                        5.9
# 2021-01-06                    339.0                        8.0
# 2021-01-07                    298.0                        5.3
# 2021-01-08                     11.0                        5.1
# ...                             ...                        ...
# 2023-07-28                    275.0                        4.7
# 2023-07-29                    242.0                       13.4
# 2023-07-30                    316.0                       16.0
# 2023-07-31                      2.0                        6.8
# 2023-08-01                    261.0                        6.2
#
#             avg_sea_level_pres_hpa_prev_3
# date
# 2021-01-04                         1021.2
# 2021-01-05                         1021.2
# 2021-01-06                         1017.8
# 2021-01-07                         1011.3
# 2021-01-08                         1014.5
# ...                                   ...
# 2023-07-28                         1007.7
# 2023-07-29                         1002.9
# 2023-07-30                         1012.6
# 2023-07-31                         1014.6
# 2023-08-01                         1011.7
#
# [940 rows x 21 columns]

# %%
features
# Out:
# ['season',
#  'avg_temp_c_prev_1',
#  'precipitation_mm_prev_1',
#  'avg_wind_dir_deg_prev_1',
#  'avg_wind_speed_kmh_prev_1',
#  'avg_sea_level_pres_hpa_prev_1',
#  'avg_temp_c_prev_2',
#  'precipitation_mm_prev_2',
#  'avg_wind_dir_deg_prev_2',
#  'avg_wind_speed_kmh_prev_2',
#  'avg_sea_level_pres_hpa_prev_2',
#  'avg_temp_c_prev_3',
#  'precipitation_mm_prev_3',
#  'avg_wind_dir_deg_prev_3',
#  'avg_wind_speed_kmh_prev_3',
#  'avg_sea_level_pres_hpa_prev_3']

# %%
target = "avg_sea_level_pres_hpa"

# %%
df_copy_4, encoders = encode_data(df_copy_3, features_to_encode=["season"], strategy="onehot", return_encoders=True)
# Out:
# D:\Fax\LAIP\VNP\packages\vnp_ez\__init__.py:138: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   feature_flags = feature_flags.replace(False, 0)

# %%
df_copy_4
# Out:
#             avg_temp_c  precipitation_mm  avg_wind_dir_deg  \
# date
# 2021-01-04         6.6               3.6             298.0
# 2021-01-05         4.3               4.6              11.0
# 2021-01-06         6.2               0.0              18.0
# 2021-01-07         7.3               0.5               0.0
# 2021-01-08         5.7               7.9             346.0
# ...                ...               ...               ...
# 2023-07-28        22.8               0.0               2.0
# 2023-07-29        26.3               0.0             261.0
# 2023-07-30        28.2               0.0             317.0
# 2023-07-31        25.8               0.0             307.0
# 2023-08-01        25.8               0.0             309.0
#
#             avg_wind_speed_kmh  avg_sea_level_pres_hpa  avg_temp_c_prev_1  \
# date
# 2021-01-04                 5.3                  1011.3                6.8
# 2021-01-05                 5.1                  1014.5                6.6
# 2021-01-06                 6.7                  1017.2                4.3
# 2021-01-07                 4.5                  1015.2                6.2
# 2021-01-08                 6.5                  1009.7                7.3
# ...                        ...                     ...                ...
# 2023-07-28                 6.8                  1014.6               20.7
# 2023-07-29                 6.2                  1011.7               22.8
# 2023-07-30                 8.0                  1009.8               26.3
# 2023-07-31                12.3                  1010.9               28.2
# 2023-08-01                 8.0                  1008.7               25.8
#
#             precipitation_mm_prev_1  avg_wind_dir_deg_prev_1  \
# date
# 2021-01-04                      1.3                    339.0
# 2021-01-05                      3.6                    298.0
# 2021-01-06                      4.6                     11.0
# 2021-01-07                      0.0                     18.0
# 2021-01-08                      0.5                      0.0
# ...                             ...                      ...
# 2023-07-28                      0.0                    316.0
# 2023-07-29                      0.0                      2.0
# 2023-07-30                      0.0                    261.0
# 2023-07-31                      0.0                    317.0
# 2023-08-01                      0.0                    307.0
#
#             avg_wind_speed_kmh_prev_1  avg_sea_level_pres_hpa_prev_1  ...  \
# date                                                                  ...
# 2021-01-04                        8.0                         1017.8  ...
# 2021-01-05                        5.3                         1011.3  ...
# 2021-01-06                        5.1                         1014.5  ...
# 2021-01-07                        6.7                         1017.2  ...
# 2021-01-08                        4.5                         1015.2  ...
# ...                               ...                            ...  ...
# 2023-07-28                       16.0                         1012.6  ...
# 2023-07-29                        6.8                         1014.6  ...
# 2023-07-30                        6.2                         1011.7  ...
# 2023-07-31                        8.0                         1009.8  ...
# 2023-08-01                       12.3                         1010.9  ...
#
#             avg_sea_level_pres_hpa_prev_2  avg_temp_c_prev_3  \
# date
# 2021-01-04                         1021.2                5.1
# 2021-01-05                         1017.8                3.0
# 2021-01-06                         1011.3                6.8
# 2021-01-07                         1014.5                6.6
# 2021-01-08                         1017.2                4.3
# ...                                   ...                ...
# 2023-07-28                         1002.9               29.2
# 2023-07-29                         1012.6               28.2
# 2023-07-30                         1014.6               20.7
# 2023-07-31                         1011.7               22.8
# 2023-08-01                         1009.8               26.3
#
#             precipitation_mm_prev_3  avg_wind_dir_deg_prev_3  \
# date
# 2021-01-04                      0.0                    330.0
# 2021-01-05                      0.0                    330.0
# 2021-01-06                      1.3                    339.0
# 2021-01-07                      3.6                    298.0
# 2021-01-08                      4.6                     11.0
# ...                             ...                      ...
# 2023-07-28                      0.0                    275.0
# 2023-07-29                      0.0                    242.0
# 2023-07-30                      0.0                    316.0
# 2023-07-31                      0.0                      2.0
# 2023-08-01                      0.0                    261.0
#
#             avg_wind_speed_kmh_prev_3  avg_sea_level_pres_hpa_prev_3  Autumn  \
# date
# 2021-01-04                        5.9                         1021.2       0
# 2021-01-05                        5.9                         1021.2       0
# 2021-01-06                        8.0                         1017.8       0
# 2021-01-07                        5.3                         1011.3       0
# 2021-01-08                        5.1                         1014.5       0
# ...                               ...                            ...     ...
# 2023-07-28                        4.7                         1007.7       0
# 2023-07-29                       13.4                         1002.9       0
# 2023-07-30                       16.0                         1012.6       0
# 2023-07-31                        6.8                         1014.6       0
# 2023-08-01                        6.2                         1011.7       0
#
#             Spring  Summer  Winter
# date
# 2021-01-04       0       0       1
# 2021-01-05       0       0       1
# 2021-01-06       0       0       1
# 2021-01-07       0       0       1
# 2021-01-08       0       0       1
# ...            ...     ...     ...
# 2023-07-28       0       1       0
# 2023-07-29       0       1       0
# 2023-07-30       0       1       0
# 2023-07-31       0       1       0
# 2023-08-01       0       1       0
#
# [940 rows x 24 columns]

# %%
encoders["season"]
# Out:
# ['Autumn', 'Spring', 'Summer', 'Winter']

# %%
features
# Out:
# ['season',
#  'avg_temp_c_prev_1',
#  'precipitation_mm_prev_1',
#  'avg_wind_dir_deg_prev_1',
#  'avg_wind_speed_kmh_prev_1',
#  'avg_sea_level_pres_hpa_prev_1',
#  'avg_temp_c_prev_2',
#  'precipitation_mm_prev_2',
#  'avg_wind_dir_deg_prev_2',
#  'avg_wind_speed_kmh_prev_2',
#  'avg_sea_level_pres_hpa_prev_2',
#  'avg_temp_c_prev_3',
#  'precipitation_mm_prev_3',
#  'avg_wind_dir_deg_prev_3',
#  'avg_wind_speed_kmh_prev_3',
#  'avg_sea_level_pres_hpa_prev_3']

# %%
# features[1:0] - so i do not get 'season', cus that is now encoded
X = df_copy_4[features[1:] + encoders["season"]]
Y = df_copy_4[target]

# %%
X
# Out:
#             avg_temp_c_prev_1  precipitation_mm_prev_1  \
# date
# 2021-01-04                6.8                      1.3
# 2021-01-05                6.6                      3.6
# 2021-01-06                4.3                      4.6
# 2021-01-07                6.2                      0.0
# 2021-01-08                7.3                      0.5
# ...                       ...                      ...
# 2023-07-28               20.7                      0.0
# 2023-07-29               22.8                      0.0
# 2023-07-30               26.3                      0.0
# 2023-07-31               28.2                      0.0
# 2023-08-01               25.8                      0.0
#
#             avg_wind_dir_deg_prev_1  avg_wind_speed_kmh_prev_1  \
# date
# 2021-01-04                    339.0                        8.0
# 2021-01-05                    298.0                        5.3
# 2021-01-06                     11.0                        5.1
# 2021-01-07                     18.0                        6.7
# 2021-01-08                      0.0                        4.5
# ...                             ...                        ...
# 2023-07-28                    316.0                       16.0
# 2023-07-29                      2.0                        6.8
# 2023-07-30                    261.0                        6.2
# 2023-07-31                    317.0                        8.0
# 2023-08-01                    307.0                       12.3
#
#             avg_sea_level_pres_hpa_prev_1  avg_temp_c_prev_2  \
# date
# 2021-01-04                         1017.8                3.0
# 2021-01-05                         1011.3                6.8
# 2021-01-06                         1014.5                6.6
# 2021-01-07                         1017.2                4.3
# 2021-01-08                         1015.2                6.2
# ...                                   ...                ...
# 2023-07-28                         1012.6               28.2
# 2023-07-29                         1014.6               20.7
# 2023-07-30                         1011.7               22.8
# 2023-07-31                         1009.8               26.3
# 2023-08-01                         1010.9               28.2
#
#             precipitation_mm_prev_2  avg_wind_dir_deg_prev_2  \
# date
# 2021-01-04                      0.0                    330.0
# 2021-01-05                      1.3                    339.0
# 2021-01-06                      3.6                    298.0
# 2021-01-07                      4.6                     11.0
# 2021-01-08                      0.0                     18.0
# ...                             ...                      ...
# 2023-07-28                      0.0                    242.0
# 2023-07-29                      0.0                    316.0
# 2023-07-30                      0.0                      2.0
# 2023-07-31                      0.0                    261.0
# 2023-08-01                      0.0                    317.0
#
#             avg_wind_speed_kmh_prev_2  avg_sea_level_pres_hpa_prev_2  \
# date
# 2021-01-04                        5.9                         1021.2
# 2021-01-05                        8.0                         1017.8
# 2021-01-06                        5.3                         1011.3
# 2021-01-07                        5.1                         1014.5
# 2021-01-08                        6.7                         1017.2
# ...                               ...                            ...
# 2023-07-28                       13.4                         1002.9
# 2023-07-29                       16.0                         1012.6
# 2023-07-30                        6.8                         1014.6
# 2023-07-31                        6.2                         1011.7
# 2023-08-01                        8.0                         1009.8
#
#             avg_temp_c_prev_3  precipitation_mm_prev_3  \
# date
# 2021-01-04                5.1                      0.0
# 2021-01-05                3.0                      0.0
# 2021-01-06                6.8                      1.3
# 2021-01-07                6.6                      3.6
# 2021-01-08                4.3                      4.6
# ...                       ...                      ...
# 2023-07-28               29.2                      0.0
# 2023-07-29               28.2                      0.0
# 2023-07-30               20.7                      0.0
# 2023-07-31               22.8                      0.0
# 2023-08-01               26.3                      0.0
#
#             avg_wind_dir_deg_prev_3  avg_wind_speed_kmh_prev_3  \
# date
# 2021-01-04                    330.0                        5.9
# 2021-01-05                    330.0                        5.9
# 2021-01-06                    339.0                        8.0
# 2021-01-07                    298.0                        5.3
# 2021-01-08                     11.0                        5.1
# ...                             ...                        ...
# 2023-07-28                    275.0                        4.7
# 2023-07-29                    242.0                       13.4
# 2023-07-30                    316.0                       16.0
# 2023-07-31                      2.0                        6.8
# 2023-08-01                    261.0                        6.2
#
#             avg_sea_level_pres_hpa_prev_3  Autumn  Spring  Summer  Winter
# date
# 2021-01-04                         1021.2       0       0       0       1
# 2021-01-05                         1021.2       0       0       0       1
# 2021-01-06                         1017.8       0       0       0       1
# 2021-01-07                         1011.3       0       0       0       1
# 2021-01-08                         1014.5       0       0       0       1
# ...                                   ...     ...     ...     ...     ...
# 2023-07-28                         1007.7       0       0       1       0
# 2023-07-29                         1002.9       0       0       1       0
# 2023-07-30                         1012.6       0       0       1       0
# 2023-07-31                         1014.6       0       0       1       0
# 2023-08-01                         1011.7       0       0       1       0
#
# [940 rows x 19 columns]

# %%
Y
# Out:
# date
# 2021-01-04    1011.3
# 2021-01-05    1014.5
# 2021-01-06    1017.2
# 2021-01-07    1015.2
# 2021-01-08    1009.7
#                ...
# 2023-07-28    1014.6
# 2023-07-29    1011.7
# 2023-07-30    1009.8
# 2023-07-31    1010.9
# 2023-08-01    1008.7
# Name: avg_sea_level_pres_hpa, Length: 940, dtype: float64

# %% [markdown]
# ## Dataset Splitting
# Partition the dataset into training and testing sets with an 80:20 ratio.
#
# **WARNING: DO NOT SHUFFLE THE DATASET.**

# %%
# Write your code here. Add as many boxes as you need.
x_train, x_test, y_train, y_test = train_test_split(X, Y, shuffle=False, test_size=0.2)

# %%
x_train
# Out:
#             avg_temp_c_prev_1  precipitation_mm_prev_1  \
# date
# 2021-01-04                6.8                      1.3
# 2021-01-05                6.6                      3.6
# 2021-01-06                4.3                      4.6
# 2021-01-07                6.2                      0.0
# 2021-01-08                7.3                      0.5
# ...                       ...                      ...
# 2023-01-21                7.4                      1.0
# 2023-01-22                4.3                      0.5
# 2023-01-23                5.8                      0.0
# 2023-01-24                8.3                      0.0
# 2023-01-25                6.3                      0.5
#
#             avg_wind_dir_deg_prev_1  avg_wind_speed_kmh_prev_1  \
# date
# 2021-01-04                    339.0                        8.0
# 2021-01-05                    298.0                        5.3
# 2021-01-06                     11.0                        5.1
# 2021-01-07                     18.0                        6.7
# 2021-01-08                      0.0                        4.5
# ...                             ...                        ...
# 2023-01-21                     91.0                        8.5
# 2023-01-22                    264.0                        8.4
# 2023-01-23                    261.0                        5.9
# 2023-01-24                    139.0                        7.8
# 2023-01-25                    254.0                        7.5
#
#             avg_sea_level_pres_hpa_prev_1  avg_temp_c_prev_2  \
# date
# 2021-01-04                         1017.8                3.0
# 2021-01-05                         1011.3                6.8
# 2021-01-06                         1014.5                6.6
# 2021-01-07                         1017.2                4.3
# 2021-01-08                         1015.2                6.2
# ...                                   ...                ...
# 2023-01-21                         1005.4               12.5
# 2023-01-22                         1010.5                7.4
# 2023-01-23                         1019.0                4.3
# 2023-01-24                         1021.6                5.8
# 2023-01-25                         1027.1                8.3
#
#             precipitation_mm_prev_2  avg_wind_dir_deg_prev_2  \
# date
# 2021-01-04                      0.0                    330.0
# 2021-01-05                      1.3                    339.0
# 2021-01-06                      3.6                    298.0
# 2021-01-07                      4.6                     11.0
# 2021-01-08                      0.0                     18.0
# ...                             ...                      ...
# 2023-01-21                      9.0                     96.0
# 2023-01-22                      1.0                     91.0
# 2023-01-23                      0.5                    264.0
# 2023-01-24                      0.0                    261.0
# 2023-01-25                      0.0                    139.0
#
#             avg_wind_speed_kmh_prev_2  avg_sea_level_pres_hpa_prev_2  \
# date
# 2021-01-04                        5.9                         1021.2
# 2021-01-05                        8.0                         1017.8
# 2021-01-06                        5.3                         1011.3
# 2021-01-07                        5.1                         1014.5
# 2021-01-08                        6.7                         1017.2
# ...                               ...                            ...
# 2023-01-21                       12.5                         1004.7
# 2023-01-22                        8.5                         1005.4
# 2023-01-23                        8.4                         1010.5
# 2023-01-24                        5.9                         1019.0
# 2023-01-25                        7.8                         1021.6
#
#             avg_temp_c_prev_3  precipitation_mm_prev_3  \
# date
# 2021-01-04                5.1                      0.0
# 2021-01-05                3.0                      0.0
# 2021-01-06                6.8                      1.3
# 2021-01-07                6.6                      3.6
# 2021-01-08                4.3                      4.6
# ...                       ...                      ...
# 2023-01-21               12.6                      0.0
# 2023-01-22               12.5                      9.0
# 2023-01-23                7.4                      1.0
# 2023-01-24                4.3                      0.5
# 2023-01-25                5.8                      0.0
#
#             avg_wind_dir_deg_prev_3  avg_wind_speed_kmh_prev_3  \
# date
# 2021-01-04                    330.0                        5.9
# 2021-01-05                    330.0                        5.9
# 2021-01-06                    339.0                        8.0
# 2021-01-07                    298.0                        5.3
# 2021-01-08                     11.0                        5.1
# ...                             ...                        ...
# 2023-01-21                    143.0                        9.1
# 2023-01-22                     96.0                       12.5
# 2023-01-23                     91.0                        8.5
# 2023-01-24                    264.0                        8.4
# 2023-01-25                    261.0                        5.9
#
#             avg_sea_level_pres_hpa_prev_3  Autumn  Spring  Summer  Winter
# date
# 2021-01-04                         1021.2       0       0       0       1
# 2021-01-05                         1021.2       0       0       0       1
# 2021-01-06                         1017.8       0       0       0       1
# 2021-01-07                         1011.3       0       0       0       1
# 2021-01-08                         1014.5       0       0       0       1
# ...                                   ...     ...     ...     ...     ...
# 2023-01-21                         1002.8       0       0       0       1
# 2023-01-22                         1004.7       0       0       0       1
# 2023-01-23                         1005.4       0       0       0       1
# 2023-01-24                         1010.5       0       0       0       1
# 2023-01-25                         1019.0       0       0       0       1
#
# [752 rows x 19 columns]

# %%
x_test
# Out:
#             avg_temp_c_prev_1  precipitation_mm_prev_1  \
# date
# 2023-01-26                4.7                      0.3
# 2023-01-27                3.3                      0.0
# 2023-01-28                1.9                      0.0
# 2023-01-29                2.9                      0.0
# 2023-01-30                2.5                      0.0
# ...                       ...                      ...
# 2023-07-28               20.7                      0.0
# 2023-07-29               22.8                      0.0
# 2023-07-30               26.3                      0.0
# 2023-07-31               28.2                      0.0
# 2023-08-01               25.8                      0.0
#
#             avg_wind_dir_deg_prev_1  avg_wind_speed_kmh_prev_1  \
# date
# 2023-01-26                     49.0                        4.0
# 2023-01-27                     94.0                        8.9
# 2023-01-28                    280.0                        9.0
# 2023-01-29                    270.0                        7.0
# 2023-01-30                    299.0                        8.7
# ...                             ...                        ...
# 2023-07-28                    316.0                       16.0
# 2023-07-29                      2.0                        6.8
# 2023-07-30                    261.0                        6.2
# 2023-07-31                    317.0                        8.0
# 2023-08-01                    307.0                       12.3
#
#             avg_sea_level_pres_hpa_prev_1  avg_temp_c_prev_2  \
# date
# 2023-01-26                         1026.2                6.3
# 2023-01-27                         1015.9                4.7
# 2023-01-28                         1010.2                3.3
# 2023-01-29                         1016.7                1.9
# 2023-01-30                         1022.9                2.9
# ...                                   ...                ...
# 2023-07-28                         1012.6               28.2
# 2023-07-29                         1014.6               20.7
# 2023-07-30                         1011.7               22.8
# 2023-07-31                         1009.8               26.3
# 2023-08-01                         1010.9               28.2
#
#             precipitation_mm_prev_2  avg_wind_dir_deg_prev_2  \
# date
# 2023-01-26                      0.5                    254.0
# 2023-01-27                      0.3                     49.0
# 2023-01-28                      0.0                     94.0
# 2023-01-29                      0.0                    280.0
# 2023-01-30                      0.0                    270.0
# ...                             ...                      ...
# 2023-07-28                      0.0                    242.0
# 2023-07-29                      0.0                    316.0
# 2023-07-30                      0.0                      2.0
# 2023-07-31                      0.0                    261.0
# 2023-08-01                      0.0                    317.0
#
#             avg_wind_speed_kmh_prev_2  avg_sea_level_pres_hpa_prev_2  \
# date
# 2023-01-26                        7.5                         1027.1
# 2023-01-27                        4.0                         1026.2
# 2023-01-28                        8.9                         1015.9
# 2023-01-29                        9.0                         1010.2
# 2023-01-30                        7.0                         1016.7
# ...                               ...                            ...
# 2023-07-28                       13.4                         1002.9
# 2023-07-29                       16.0                         1012.6
# 2023-07-30                        6.8                         1014.6
# 2023-07-31                        6.2                         1011.7
# 2023-08-01                        8.0                         1009.8
#
#             avg_temp_c_prev_3  precipitation_mm_prev_3  \
# date
# 2023-01-26                8.3                      0.0
# 2023-01-27                6.3                      0.5
# 2023-01-28                4.7                      0.3
# 2023-01-29                3.3                      0.0
# 2023-01-30                1.9                      0.0
# ...                       ...                      ...
# 2023-07-28               29.2                      0.0
# 2023-07-29               28.2                      0.0
# 2023-07-30               20.7                      0.0
# 2023-07-31               22.8                      0.0
# 2023-08-01               26.3                      0.0
#
#             avg_wind_dir_deg_prev_3  avg_wind_speed_kmh_prev_3  \
# date
# 2023-01-26                    139.0                        7.8
# 2023-01-27                    254.0                        7.5
# 2023-01-28                     49.0                        4.0
# 2023-01-29                     94.0                        8.9
# 2023-01-30                    280.0                        9.0
# ...                             ...                        ...
# 2023-07-28                    275.0                        4.7
# 2023-07-29                    242.0                       13.4
# 2023-07-30                    316.0                       16.0
# 2023-07-31                      2.0                        6.8
# 2023-08-01                    261.0                        6.2
#
#             avg_sea_level_pres_hpa_prev_3  Autumn  Spring  Summer  Winter
# date
# 2023-01-26                         1021.6       0       0       0       1
# 2023-01-27                         1027.1       0       0       0       1
# 2023-01-28                         1026.2       0       0       0       1
# 2023-01-29                         1015.9       0       0       0       1
# 2023-01-30                         1010.2       0       0       0       1
# ...                                   ...     ...     ...     ...     ...
# 2023-07-28                         1007.7       0       0       1       0
# 2023-07-29                         1002.9       0       0       1       0
# 2023-07-30                         1012.6       0       0       1       0
# 2023-07-31                         1014.6       0       0       1       0
# 2023-08-01                         1011.7       0       0       1       0
#
# [188 rows x 19 columns]

# %% [markdown]
# ## Ensemble Learning Methods

# %% [markdown]
# ### Bagging

# %% [markdown]
# Create an instance of a Random Forest model and train it using the `fit` function.

# %%
# Write your code here. Add as many boxes as you need.
forest_regressor = RandomForestRegressor(random_state=0, n_estimators=100, max_depth=8)
forest_regressor.fit(x_train, y_train)
# Out:
# RandomForestRegressor(max_depth=8, random_state=0)

# %% [markdown]
# Use the trained model to make predictions for the test set.

# %%
# Write your code here. Add as many boxes as you need.
forest_regressor_predict = forest_regressor.predict(x_test)

# %% [markdown]
# Assess the performance of the model by using different metrics provided by the `scikit-learn` library.

# %%
# Write your code here. Add as many boxes as you need.
regression_report(y_test, forest_regressor_predict)
# Out:
# Regression Report:
# Mean Square Error: 12.259902815676082
# R2 Score: 0.7219277143285894

# %% [markdown]
# ### Boosting

# %% [markdown]
# Create an instance of an XGBoost model and train it using the `fit` function.

# %%
# Write your code here. Add as many boxes as you need.
xgb_regressor = XGBRegressor(random_state=0, n_estimators=100, max_depth=3)
xgb_regressor.fit(x_train, y_train)
# Out:
# XGBRegressor(base_score=None, booster=None, callbacks=None,
#              colsample_bylevel=None, colsample_bynode=None,
#              colsample_bytree=None, device=None, early_stopping_rounds=None,
#              enable_categorical=False, eval_metric=None, feature_types=None,
#              gamma=None, grow_policy=None, importance_type=None,
#              interaction_constraints=None, learning_rate=None, max_bin=None,
#              max_cat_threshold=None, max_cat_to_onehot=None,
#              max_delta_step=None, max_depth=3, max_leaves=None,
#              min_child_weight=None, missing=nan, monotone_constraints=None,
#              multi_strategy=None, n_estimators=100, n_jobs=None,
#              num_parallel_tree=None, random_state=0, ...)

# %% [markdown]
# Use the trained model to make predictions for the test set.

# %%
# Write your code here. Add as many boxes as you need.
xgb_regressor_predict = xgb_regressor.predict(x_test)

# %% [markdown]
# Assess the performance of the model by using different metrics provided by the `scikit-learn` library.

# %%
# Write your code here. Add as many boxes as you need.
regression_report(y_test, xgb_regressor_predict)
# Out:
# Regression Report:
# Mean Square Error: 13.737465102639234
# R2 Score: 0.6884144696858698

# %%
show_time_series_predicts(y_test, forest_regressor_predict)

# %%
show_time_series_predicts(y_test, xgb_regressor_predict)

# %% [markdown]
# # Laboratory Exercise - Bonus Task (+ 2 points)

# %% [markdown]
# As part of the bonus task in this laboratory assignment, your objective is to fine-tune the max_depth (`max_depth`) for the Random Forest model using a cross-validation with grid search and time series split. This involves systematically experimenting with various values for `max_depth` and evaluating the model's performance using cross-validation. Upon determining the most suitable `max_depth` value, evaluate the model's performance on a test set for final assessment.
#
# Hints:
# - For grid search use the `GridCVSearch` from the `scikit-learn` library. Check the documentation at https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.GridSearchCV.html.
# - For cross-validation use the `TimeSeriesSplit` from the `scikit-learn` library. Check the documentation at https://scikit-learn.org/stable/modules/generated/sklearn.model_selection.TimeSeriesSplit.html.

# %% [markdown]
# ## Dataset Splitting
# Partition the dataset into training and testing sets with an 90:10 ratio.
#
# **WARNING: DO NOT SHUFFLE THE DATASET.**

# %%
# Write your code here. Add as many boxes as you need.
x_train1, x_test1, y_train1, y_test1 = train_test_split(X, Y, shuffle=False, test_size=0.1)

# %% [markdown]
# ## Fine-tuning the Random Forest Hyperparameter
# Experiment with various values for `max_depth` and evaluate the model's performance using cross-validation.

# %%
# Write your code here. Add as many boxes as you need.
param_grid = {
    "max_depth": [None, 5, 8, 10, 12],
    # "random_state":[0]
}

# %%
grid_search_cv = GridSearchCV(RandomForestRegressor(), param_grid=param_grid, cv=TimeSeriesSplit(5), scoring="r2")

# %%
grid_search_cv.fit(x_train1, y_train1)
# Out:
# GridSearchCV(cv=TimeSeriesSplit(gap=0, max_train_size=None, n_splits=5, test_size=None),
#              estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 5, 8, 10, 12]}, scoring='r2')

# %%
grid_search_cv.best_params_
# Out:
# {'max_depth': 8}

# %%
grid_search_cv.best_score_
# Out:
# np.float64(0.6952682608308004)

# %% [markdown]
# ## Final Assessment of the Model Performance
# Upon determining the most suitable `max_depth` value, evaluate the model's performance on a test set for final assessment.

# %%
# Write your code here. Add as many boxes as you need.
best_estimator = grid_search_cv.best_estimator_
best_estimator_predict = best_estimator.predict(x_test1)

# %%
regression_report(y_test1,best_estimator_predict)
# Out:
# Regression Report:
# Mean Square Error: 4.507053911562779
# R2 Score: 0.580498609248393

# %%
show_time_series_predicts(y_test1, best_estimator_predict)
